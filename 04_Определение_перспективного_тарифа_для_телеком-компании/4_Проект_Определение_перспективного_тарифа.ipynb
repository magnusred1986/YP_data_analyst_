# %% [markdown]
# <a name="contents"></a>
#  [Огравление](#stage_1)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Изучение-информации,-предобработка,-подготовка" data-toc-modified-id="Изучение-информации,-предобработка,-подготовка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение информации, предобработка, подготовка</a></span><ul class="toc-item"><li><span><a href="#Таблица-users-(информация-о-пользователях)" data-toc-modified-id="Таблица-users-(информация-о-пользователях)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Таблица <code>users</code> (информация о пользователях)</a></span></li><li><span><a href="#Таблица-calls-(информация-о-звонках)" data-toc-modified-id="Таблица-calls-(информация-о-звонках)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Таблица <code>calls</code> (информация о звонках)</a></span></li><li><span><a href="#Таблица-messages-(информация-о-сообщениях)" data-toc-modified-id="Таблица-messages-(информация-о-сообщениях)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Таблица <code>messages</code> (информация о сообщениях)</a></span></li><li><span><a href="#Таблица-internet-(информация-об-интернет--сессиях)" data-toc-modified-id="Таблица-internet-(информация-об-интернет--сессиях)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Таблица <code>internet</code> (информация об интернет- сессиях)</a></span></li><li><span><a href="#Таблица-tariffs-(информация-о-тарифах)" data-toc-modified-id="Таблица-tariffs-(информация-о-тарифах)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Таблица <code>tariffs</code> (информация о тарифах)</a></span></li><li><span><a href="#Добавление-столбца-месяц-в-DF-ы" data-toc-modified-id="Добавление-столбца-месяц-в-DF-ы-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Добавление столбца месяц в DF-ы</a></span></li><li><span><a href="#Количество-звонков-и-израсходованных-минут-разговора,-объем-интернета-по-месяцам" data-toc-modified-id="Количество-звонков-и-израсходованных-минут-разговора,-объем-интернета-по-месяцам-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Количество звонков и израсходованных минут разговора, объем интернета по месяцам</a></span></li></ul></li><li><span><a href="#Объединим-данные,-посчитаем-помесячную-выручку" data-toc-modified-id="Объединим-данные,-посчитаем-помесячную-выручку-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Объединим данные, посчитаем помесячную выручку</a></span><ul class="toc-item"><li><span><a href="#Перерасход-звонков.-Вычтем-бесплатный-лимит-из-суммарного-количества-звонков" data-toc-modified-id="Перерасход-звонков.-Вычтем-бесплатный-лимит-из-суммарного-количества-звонков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Перерасход звонков. Вычтем бесплатный лимит из суммарного количества звонков</a></span></li><li><span><a href="#Перерасход-смс.-Вычтем-лимит-соощений" data-toc-modified-id="Перерасход-смс.-Вычтем-лимит-соощений-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Перерасход смс. Вычтем лимит соощений</a></span></li><li><span><a href="#Перерасход-интернет-трафика.-Вычтем-лимит-трафика" data-toc-modified-id="Перерасход-интернет-трафика.-Вычтем-лимит-трафика-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Перерасход интернет-трафика. Вычтем лимит трафика</a></span></li><li><span><a href="#Выручка-(сборка)" data-toc-modified-id="Выручка-(сборка)-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выручка (сборка)</a></span><ul class="toc-item"><li><span><a href="#Выручка-за-перерасход-звонков" data-toc-modified-id="Выручка-за-перерасход-звонков-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Выручка за перерасход звонков</a></span></li><li><span><a href="#Выручка-за-перерасход-смс" data-toc-modified-id="Выручка-за-перерасход-смс-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Выручка за перерасход смс</a></span></li><li><span><a href="#Выручка-за-перерасход-Гб" data-toc-modified-id="Выручка-за-перерасход-Гб-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Выручка за перерасход Гб</a></span></li><li><span><a href="#Общая-выручка" data-toc-modified-id="Общая-выручка-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Общая выручка</a></span></li></ul></li><li><span><a href="#Выручка-по-месяцам" data-toc-modified-id="Выручка-по-месяцам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выручка по месяцам</a></span></li><li><span><a href="#Распределение-выручки-в-зависимости-от-тарифа" data-toc-modified-id="Распределение-выручки-в-зависимости-от-тарифа-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Распределение выручки в зависимости от тарифа</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-услуг-по-клиентам" data-toc-modified-id="Распределение-услуг-по-клиентам-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Распределение услуг по клиентам</a></span></li><li><span><a href="#Активность-использования-услуг-smart-и-ultra-в-разбивке:-звонки,-смс,-интернет" data-toc-modified-id="Активность-использования-услуг-smart-и-ultra-в-разбивке:-звонки,-смс,-интернет-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Активность использования услуг smart и ultra в разбивке: звонки, смс, интернет</a></span></li></ul></li><li><span><a href="#Дозаказ-услуг-всего-и-в-разбивке" data-toc-modified-id="Дозаказ-услуг-всего-и-в-разбивке-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Дозаказ услуг всего и в разбивке</a></span><ul class="toc-item"><li><span><a href="#Интернет-трафик" data-toc-modified-id="Интернет-трафик-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Интернет-трафик</a></span></li><li><span><a href="#Звонки" data-toc-modified-id="Звонки-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Звонки</a></span></li><li><span><a href="#СМС" data-toc-modified-id="СМС-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>СМС</a></span></li><li><span><a href="#Выручка-сверх-тарифа" data-toc-modified-id="Выручка-сверх-тарифа-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Выручка сверх тарифа</a></span></li><li><span><a href="#Количество-пользователей-сверх-тарифа-(распределение-по-ultra-и-smart)" data-toc-modified-id="Количество-пользователей-сверх-тарифа-(распределение-по-ultra-и-smart)-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Количество пользователей сверх тарифа (распределение по <code>ultra</code> и <code>smart</code>)</a></span></li><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Гистограммы-переплат" data-toc-modified-id="Гистограммы-переплат-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Гистограммы переплат</a></span></li><li><span><a href="#Медиана,-cреднее,-дисперсия,-стандартнное-отклонение-по-набору-данных" data-toc-modified-id="Медиана,-cреднее,-дисперсия,-стандартнное-отклонение-по-набору-данных-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Медиана, cреднее, дисперсия, стандартнное отклонение по набору данных</a></span></li><li><span><a href="#Гистограммы-распределения-по-набору-данных:-звонкам,-смс,-интернет" data-toc-modified-id="Гистограммы-распределения-по-набору-данных:-звонкам,-смс,-интернет-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Гистограммы распределения по набору данных: звонкам, смс, интернет</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-о-равенстве-сосвокупностей-№1" data-toc-modified-id="Гипотеза-о-равенстве-сосвокупностей-№1-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Гипотеза о равенстве сосвокупностей №1</a></span></li><li><span><a href="#Гипотеза-о-равенстве-двух-средних-генеральных-совокупностях-№2" data-toc-modified-id="Гипотеза-о-равенстве-двух-средних-генеральных-совокупностях-№2-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Гипотеза о равенстве двух средних генеральных совокупностях №2</a></span></li></ul></li><li><span><a href="#Обший-вывод" data-toc-modified-id="Обший-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Обший вывод</a></span></li></ul></div>

# %% [markdown]
# ##  Описание проекта
#
# Вы аналитик компании «Мегалайн» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.
#
# Вам предстоит сделать предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
#
# # Описание тарифов
#
# **Тариф «Смарт»**
#
# 1. Ежемесячная плата: 550 рублей
# 2. Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
# 3. Стоимость услуг сверх тарифного пакета: минута разговора: 3 рубля («Мегалайн» всегда округляет вверх значения минут и мегабайтов.  Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута); сообщение: 3 рубля; 3. 1 Гб интернет-трафика: 200 рублей.
#
# **Тариф «Ультра»**
#
# 1. Ежемесячная плата: 1950 рублей
# 2. Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
# 3. Стоимость услуг сверх тарифного пакета: 1. минута разговора: 1 рубль; 2. сообщение: 1 рубль; 3. 1 Гб интернет-трафика: 150 рублей.
#
# **Примечание:**
#
# * «Мегалайн» всегда округляет секунды до минут, а мегабайты — до гигабайт.
# * Каждый звонок округляется отдельно: даже если он длился всего 1 секунду, будет засчитан как 1 минута.
# * Для веб-трафика отдельные сессии не считаются. Вместо этого общая сумма за месяц округляется в бо́льшую сторону.
# * Если абонент использует 1025 мегабайт в этом месяце, с него возьмут плату за 2 гигабайта.
#
# # Инструкция по выполнению проекта
#
# **Шаг 1. Откройте файл с данными и изучите общую информацию**
#
# Путь к файлам:
#
# * /datasets/`calls`.csv. Скачать датасет
# * /datasets/`internet`.csv. Скачать датасет
# * /datasets/`messages`.csv. Скачать датасет
# * /datasets/`tariffs`.csv. Скачать датасет
# * /datasets/`users`.csv. Скачать датасет
#
# **Шаг 2. Подготовьте данные**
#
# * Приведите данные к нужным типам;
# * Найдите и исправьте ошибки в данных, если они есть.
#
# Поясните, какие ошибки вы нашли и как их исправили. В данных вы найдёте звонки с нулевой продолжительностью. Это не ошибка: нулями обозначены пропущенные звонки, поэтому их не нужно удалять.
#
# Посчитайте для каждого пользователя:
#
# * количество сделанных звонков и израсходованных минут разговора по месяцам;
# * количество отправленных сообщений по месяцам;
# * объем израсходованного интернет-трафика по месяцам;
# * помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).
#
# **Шаг 3. Проанализируйте данные**
#
# Опишите поведение клиентов оператора, исходя из выборки.
# Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц?
# Посчитайте среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения.
#
# **Шаг 4. Проверьте гипотезы**
#
# * средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются;
# * средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.
# Пороговое значение alpha задайте самостоятельно.
#
# ***Поясните:***
# * как вы формулировали нулевую и альтернативную гипотезы;
# * какой критерий использовали для проверки гипотез и почему.
#
# **Шаг 5. Напишите общий вывод**
#
# Оформление:
#
# Задание выполните в Jupyter Notebook. Программный код заполните в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
# # Описание данных
#
# **Таблица `users` (информация о пользователях):**
#
# * user_id — уникальный идентификатор пользователя
# * first_name — имя пользователя
# * last_name — фамилия пользователя
# * age — возраст пользователя (годы)
# * reg_date — дата подключения тарифа (день, месяц, год)
# * churn_date — дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# * city — город проживания пользователя
# * tarif — название тарифного плана
#
# **Таблица `calls` (информация о звонках):**
#
# * id — уникальный номер звонка
# * call_date — дата звонка
# * duration — длительность звонка в минутах
# * user_id — идентификатор пользователя, сделавшего звонок
#
# **Таблица `messages` (информация о сообщениях):**
#
# * id — уникальный номер сообщения
# * message_date — дата сообщения
# * user_id — идентификатор пользователя, отправившего сообщение
#
# **Таблица `internet` (информация об интернет-сессиях):**
#
# * id — уникальный номер сессии
# * mb_used — объём потраченного за сессию интернет-трафика (в мегабайтах)
# * session_date — дата интернет-сессии
# * user_id — идентификатор пользователя
#
# **Таблица `tariffs` (информация о тарифах):**
#
# * tariff_name — название тарифа
# * rub_monthly_fee — ежемесячная абонентская плата в рублях
# * minutes_included — количество минут разговора в месяц, включённых в абонентскую плату
# * messages_included — количество сообщений в месяц, включённых в абонентскую плату
# * mb_per_month_included — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# * rub_per_minute — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# * rub_per_message — стоимость отправки сообщения сверх тарифного пакета
# * rub_per_gb — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %% [markdown]
# ## Изучение информации, предобработка, подготовка

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Подгружаем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import matplotlib.patches as mpatches
from scipy import stats as st
# %matplotlib inline указывает, что график необходимо построить все в той же оболочке Jupyter,
# но теперь он выводится как обычная картинка. Данный способ удобен тем,
# что позволяет проводить очень много экспериментов в рамках одного окна (точнее web-страницы)

# %% [markdown]
# Подгружаем БД

# %%
users = pd.read_csv('/datasets/users.csv')
calls = pd.read_csv('/datasets/calls.csv')
internet = pd.read_csv('/datasets/internet.csv')
messages = pd.read_csv('/datasets/messages.csv')
tariffs = pd.read_csv('/datasets/tariffs.csv')

# %% [markdown]
# ### Таблица `users` (информация о пользователях)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
users.head()
# Out:
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra

# %%
users['age'].describe().round(0) # смотрим только 1 столбец, т.к. только по нему будет статистика, округл до 0 зн
# Out:
# count    500.0
# mean      47.0
# std       17.0
# min       18.0
# 25%       32.0
# 50%       46.0
# 75%       62.0
# max       75.0
# Name: age, dtype: float64

# %% [markdown]
# Проверим `users` на дубликаты

# %%
print('Дубликатов по users:', users.duplicated().sum())
# Out:
# Дубликатов по users: 0

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# user_id       500 non-null int64
# age           500 non-null int64
# churn_date    38 non-null object
# city          500 non-null object
# first_name    500 non-null object
# last_name     500 non-null object
# reg_date      500 non-null object
# tariff        500 non-null object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %% [markdown]
# Много  пропусков в `churn_date` согласно условию: `churn_date` — *дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных).*
# Значит ничего не правим в данном столбце.
#
# Видим формарт типа `object` в столбцах `churn_date` и `reg_date`, который нужно заменить на `datetime`

# %%
users.index[~users['churn_date'].isnull()] # выведем индексы с датами (~ не с пустыми значениями)
# Out:
# Int64Index([ 19,  20,  34,  50,  51,  56,  62,  63,  64,  65,  71,  90, 128,
#             161, 163, 191, 201, 206, 232, 242, 254, 255, 265, 271, 293, 343,
#             353, 355, 367, 370, 371, 392, 399, 416, 422, 438, 480, 498],
#            dtype='int64')

# %%
users[19:35] # сделам выборочный срез и убедимся, что они есть и формат соотв-ует столбцу reg_date
# Out:
#     user_id  age  churn_date             city first_name   last_name  \
# 19     1019   63  2018-10-05            Томск    Игнатий     Круглов
# 20     1020   59  2018-12-18             Чита       Тала     Костина
# 21     1021   61         NaN        Краснодар  Святослав     Тихонов
# 22     1022   72         NaN  Санкт-Петербург   Василиса   Трофимова
# 23     1023   42         NaN            Томск    Людмила  Мельникова
# 24     1024   73         NaN  Санкт-Петербург     Иулиан     Антипов
# 25     1025   56         NaN              Уфа     Матвей      Акинин
# 26     1026   32         NaN         Мурманск    Евгений     Бородин
# 27     1027   62         NaN     Петрозаводск  Владислав      Авдеев
# 28     1028   20         NaN            Тверь     Рустем      Евсеев
# 29     1029   51         NaN     Екатеринбург    Алексей    Селезнев
# 30     1030   28         NaN        Махачкала   Мариетта    Русанова
# 31     1031   66         NaN           Москва  Лаврентий    Тимофеев
# ...

# %% [markdown]
# Изменим тип данных в столбцах `churn_date` и `reg_date` на `datetime`

# %%
users['churn_date'] = pd.to_datetime(users['churn_date'], format = '%Y-%m-%d')
users['reg_date'] = pd.to_datetime(users['reg_date'], format = '%Y-%m-%d')

# %% [markdown]
# Проверим изменения

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# user_id       500 non-null int64
# age           500 non-null int64
# churn_date    38 non-null datetime64[ns]
# city          500 non-null object
# first_name    500 non-null object
# last_name     500 non-null object
# reg_date      500 non-null datetime64[ns]
# tariff        500 non-null object
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 31.4+ KB

# %%
users[19:35] # срез
# Out:
#     user_id  age churn_date             city first_name   last_name  \
# 19     1019   63 2018-10-05            Томск    Игнатий     Круглов
# 20     1020   59 2018-12-18             Чита       Тала     Костина
# 21     1021   61        NaT        Краснодар  Святослав     Тихонов
# 22     1022   72        NaT  Санкт-Петербург   Василиса   Трофимова
# 23     1023   42        NaT            Томск    Людмила  Мельникова
# 24     1024   73        NaT  Санкт-Петербург     Иулиан     Антипов
# 25     1025   56        NaT              Уфа     Матвей      Акинин
# 26     1026   32        NaT         Мурманск    Евгений     Бородин
# 27     1027   62        NaT     Петрозаводск  Владислав      Авдеев
# 28     1028   20        NaT            Тверь     Рустем      Евсеев
# 29     1029   51        NaT     Екатеринбург    Алексей    Селезнев
# 30     1030   28        NaT        Махачкала   Мариетта    Русанова
# 31     1031   66        NaT           Москва  Лаврентий    Тимофеев
# ...

# %% [markdown]
# Тип данных изменен

# %% [markdown]
# ### Таблица `calls` (информация о звонках)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
calls.head()
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000

# %% [markdown]
# Так как в условии длительность звонка `duration` в минутах и посчистать нужно
# (количество сделанных звонков и израсходованных минут разговора по месяцам),
# округлим данные `np.ceil` (в большую сторону) приведем тип данных в целочисленный тип `int`
#
# *Из условий Мегалайна:
# («Мегалайн» всегда округляет вверх значения минут и мегабайтов.
# Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута)*

# %%
calls['duration'] = calls['duration'].apply(np.ceil).astype('int')

# %% [markdown]
# Проверим изменения

# %%
calls.head()
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25         0     1000
# 1  1000_1  2018-08-17         0     1000
# 2  1000_2  2018-06-11         3     1000
# 3  1000_3  2018-09-21        14     1000
# 4  1000_4  2018-12-15         6     1000

# %%
calls.describe().round(2)
# Out:
#         duration    user_id
# count  202607.00  202607.00
# mean        7.16    1253.94
# std         5.96     144.72
# min         0.00    1000.00
# 25%         2.00    1126.00
# 50%         6.00    1260.00
# 75%        11.00    1379.00
# max        38.00    1499.00

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null object
# call_date    202607 non-null object
# duration     202607 non-null int64
# user_id      202607 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# Тип данных `int` и округление `np.ceil` применено к столбцу `duration`
#
# Нужно изменить тип данных столбца `call_date` с `object` на `datatime`

# %%
calls['call_date'] = pd.to_datetime(calls['call_date'], format = "%Y-%m-%d")

# %% [markdown]
# Проверим изменения

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null object
# call_date    202607 non-null datetime64[ns]
# duration     202607 non-null int64
# user_id      202607 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 6.2+ MB

# %% [markdown]
# Тип данных по столбцу `call_date` изменен на `datetime`

# %% [markdown]
# Проверим `calls` на дубликаты

# %%
print('Дубликатов по calls:', calls.duplicated().sum())
# Out:
# Дубликатов по calls: 0

# %% [markdown]
# Посмотрим на количество звонков 0 минут

# %%
calls.groupby('duration')['user_id'].count()
# Out:
# duration
# 0     39613
# 1      8402
# 2      9194
# 3     10362
# 4     10918
# 5     11411
# 6     11457
# 7     11510
# 8     11272
# 9     10973
# 10    10186
# 11     9385
# 12     8448
# 13     7486
# 14     6554
# 15     5505
# 16     4551
# 17     3671
# 18     2984
# 19     2411
# 20     1806
# 21     1304
# 22      975
# 23      720
# 24      468
# 25      363
# 26      257
# 27      151
# 28      104
# 29       56
# 30       39
# 31       30
# 32       17
# 33       10
# 34        3
# 35        5
# 36        2
# 37        2
# 38        2
# Name: user_id, dtype: int64

# %%
calls.query('duration == 0')
# Out:
#               id  call_date  duration  user_id
# 0         1000_0 2018-07-25         0     1000
# 1         1000_1 2018-08-17         0     1000
# 5         1000_5 2018-11-02         0     1000
# 6         1000_6 2018-10-18         0     1000
# 9         1000_9 2018-08-15         0     1000
# ...          ...        ...       ...      ...
# 202590  1499_203 2018-12-03         0     1499
# 202592  1499_205 2018-10-13         0     1499
# 202593  1499_206 2018-12-26         0     1499
# 202594  1499_207 2018-10-28         0     1499
# 202596  1499_209 2018-12-16         0     1499
#
# [39613 rows x 4 columns]

# %%
print('Количество звонков продолжительностью 0 минут :' ,calls[calls['duration'] == 0].shape[0])
# Out:
# Количество звонков продолжительностью 0 минут : 39613

# %% [markdown]
# Построим гистограмму для визуализации звонков

# %%
calls.plot(y = 'duration', kind = 'hist', bins = 35, grid=True, figsize = (6,6), range=(0,35))
plt.plot()
plt.title("Количество звонков в минутах", fontsize=12, fontweight="bold")
plt.xlabel("минуты", fontsize=12, fontweight="bold")
plt.ylabel("количество", fontsize=12, fontweight="bold")
# Out:
# Text(0, 0.5, 'количество')

# %% [markdown]
# Так как согласно условиям проекта секунды оруглены в большую сторону, даже если диалог был пару секунд,
# вероятнее всего это неотвеченные вызовы - линия занята, которыя являются выбросами. их нужно будет удалить

# %%
calls['duration'] = calls['duration'].replace(0, np.NaN) # заменим 0 на NaN

# %% [markdown]
# Проверим изменения

# %%
calls.plot(y = 'duration', kind = 'hist', bins = 35, grid=True, figsize = (6,6), range=(0,35))
plt.plot()
plt.title("Количество звонков в минутах", fontsize=12, fontweight="bold")
plt.xlabel("минуты", fontsize=12, fontweight="bold")
plt.ylabel("количество", fontsize=12, fontweight="bold")
# Out:
# Text(0, 0.5, 'количество')

# %% [markdown]
# ### Таблица `messages` (информация о сообщениях)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
# сделаем ленивку, раз уж у нас не одна БД
qw = messages
print('----------------------------------------------------ГОЛОВА')
display(qw.head())
print('----------------------------------------------------СТАТИСТИКА')
display(qw.describe().round(2))
print('----------------------------------------------------ИНФО')
display(qw.info())
print('----------------------------------------------------РАНДОМ')
display(qw.sample(10))
print('----------------------------------------------------ДУБЛИКАТЫ')
print('Дубликатов по calls:', qw.duplicated().sum())
# Out:
# ----------------------------------------------------ГОЛОВА
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000
# ----------------------------------------------------СТАТИСТИКА
#          user_id
# count  123036.00
# mean     1256.99
# std       143.52
# min      1000.00
# 25%      1134.00
# 50%      1271.00
# 75%      1381.00
# max      1499.00
# ----------------------------------------------------ИНФО
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null object
# message_date    123036 non-null object
# user_id         123036 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB
# None
# ----------------------------------------------------РАНДОМ
#               id message_date  user_id
# ...

# %% [markdown]
# Необходимо изменить тип данных столбца `message_date` на `datetime`

# %%
messages['message_date'] = pd.to_datetime(messages['message_date'], format = "%Y-%m-%d")

# %% [markdown]
# Проверим изменения

# %%
qw = messages
print('----------------------------------------------------ГОЛОВА')
display(qw.head())
print('----------------------------------------------------СТАТИСТИКА')
display(qw.describe().round(2))
print('----------------------------------------------------ИНФО')
display(qw.info())
print('----------------------------------------------------РАНДОМ')
display(qw.sample(10))
print('----------------------------------------------------ДУБЛИКАТЫ')
print('Дубликатов по calls:', qw.duplicated().sum())
# Out:
# ----------------------------------------------------ГОЛОВА
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000
# ----------------------------------------------------СТАТИСТИКА
#          user_id
# count  123036.00
# mean     1256.99
# std       143.52
# min      1000.00
# 25%      1134.00
# 50%      1271.00
# 75%      1381.00
# max      1499.00
# ----------------------------------------------------ИНФО
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null object
# message_date    123036 non-null datetime64[ns]
# user_id         123036 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.8+ MB
# None
# ----------------------------------------------------РАНДОМ
#               id message_date  user_id
# ...

# %% [markdown]
# ### Таблица `internet` (информация об интернет- сессиях)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
qw = internet
print('----------------------------------------------------ГОЛОВА')
display(qw.head())
print('----------------------------------------------------СТАТИСТИКА')
display(qw.describe().round(2))
print('----------------------------------------------------ИНФО')
display(qw.info())
print('----------------------------------------------------РАНДОМ')
display(qw.sample(10))
print('----------------------------------------------------ДУБЛИКАТЫ')
print('Дубликатов по calls:', qw.duplicated().sum())
# Out:
# ----------------------------------------------------ГОЛОВА
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000
# ----------------------------------------------------СТАТИСТИКА
#        Unnamed: 0    mb_used    user_id
# count   149396.00  149396.00  149396.00
# mean     74697.50     370.19    1252.10
# std      43127.05     278.30     144.05
# min          0.00       0.00    1000.00
# 25%      37348.75     138.19    1130.00
# 50%      74697.50     348.02    1251.00
# 75%     112046.25     559.55    1380.00
# max     149395.00    1724.83    1499.00
# ----------------------------------------------------ИНФО
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# ...

# %% [markdown]
# Избавимся от столбца `Unnamed: 0`, тип данных столбца `session_date`привести к `datetime`, округлить данные в столбце `mb_used` («Мегалайн» всегда округляет вверх значения минут и мегабайтов. Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута)

# %%
internet = internet[['id','mb_used','session_date','user_id']] # оставим нужные столбцы
pd.set_option('chained_assignment', None) # скрывает предупреждения
# или так internet = df_internet[list(internet.columns)[1:5]]
# 1 internet['mb_used'] = internet['mb_used'].apply(np.ceil) # округляем в большую сторону
# 2 internet['mb_used'] = internet['mb_used'].astype(np.int64, errors='ignore') # изменили тип данных, ошибки Nan игнорируем
internet['mb_used'] = internet['mb_used'].astype(np.float64, errors='ignore')
internet['session_date'] = pd.to_datetime(internet['session_date'], format = "%Y-%m-%d")
pd.set_option('chained_assignment', None) # скрывает предупреждения

# %%
display(qw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
# Unnamed: 0      149396 non-null int64
# id              149396 non-null object
# mb_used         149396 non-null float64
# session_date    149396 non-null object
# user_id         149396 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB
# None

# %%
qw
# Out:
#         Unnamed: 0        id  mb_used session_date  user_id
# 0                0    1000_0   112.95   2018-11-25     1000
# 1                1    1000_1  1052.81   2018-09-07     1000
# 2                2    1000_2  1197.26   2018-06-25     1000
# 3                3    1000_3   550.27   2018-08-22     1000
# 4                4    1000_4   302.56   2018-09-24     1000
# ...            ...       ...      ...          ...      ...
# 149391      149391  1499_152   318.90   2018-10-03     1499
# 149392      149392  1499_153   490.13   2018-12-14     1499
# 149393      149393  1499_154     0.00   2018-10-27     1499
# 149394      149394  1499_155  1246.32   2018-11-26     1499
# 149395      149395  1499_156   544.37   2018-10-26     1499
#
# [149396 rows x 5 columns]

# %% [markdown]
# Проверим изменения

# %%
qw = internet
print('----------------------------------------------------ГОЛОВА')
display(qw.head())
print('----------------------------------------------------СТАТИСТИКА')
display(qw.describe().round(2))
print('----------------------------------------------------ИНФО')
display(qw.info())
print('----------------------------------------------------РАНДОМ')
display(qw.sample(10))
print('----------------------------------------------------ДУБЛИКАТЫ')
print('Дубликатов по calls:', qw.duplicated().sum())
# Out:
# ----------------------------------------------------ГОЛОВА
#        id  mb_used session_date  user_id
# 0  1000_0   112.95   2018-11-25     1000
# 1  1000_1  1052.81   2018-09-07     1000
# 2  1000_2  1197.26   2018-06-25     1000
# 3  1000_3   550.27   2018-08-22     1000
# 4  1000_4   302.56   2018-09-24     1000
# ----------------------------------------------------СТАТИСТИКА
#          mb_used    user_id
# count  149396.00  149396.00
# mean      370.19    1252.10
# std       278.30     144.05
# min         0.00    1000.00
# 25%       138.19    1130.00
# 50%       348.02    1251.00
# 75%       559.55    1380.00
# max      1724.83    1499.00
# ----------------------------------------------------ИНФО
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 4 columns):
# id              149396 non-null object
# mb_used         149396 non-null float64
# session_date    149396 non-null datetime64[ns]
# ...

# %% [markdown]
# Данные окргулены по `mb_used` изменен тип данных `session_date`

# %% [markdown]
# Построим гистограмму распределения использования интернета

# %%
# переменные хранящая данные max и min значения для корректного построения гистограммы
max_range_mb_used = internet['mb_used'].max()
min_range_mb_used = internet['mb_used'].min()

# %%
internet.plot(y = 'mb_used', kind = 'hist', bins = 50, grid=True, figsize = (6,6), range=(min_range_mb_used,max_range_mb_used))
plt.plot()
plt.title("Использование интернет-трафика", fontsize=12, fontweight="bold")
plt.xlabel("объём потраченного за сессию интернет-трафика (в мегабайтах)", fontsize=12, fontweight="bold")
plt.ylabel("сессий", fontsize=12, fontweight="bold")

# но можно было и просто internet.plot(y = 'mb_used', kind = 'hist', bins = 50)
# Out:
# Text(0, 0.5, 'сессий')

# %% [markdown]
# Ситтуация как и со звонками, взглянем на колличество 0 сессий

# %%
internet.query('mb_used == 0')
# Out:
#               id  mb_used session_date  user_id
# 11       1000_11      0.0   2018-08-28     1000
# 38       1000_38      0.0   2018-11-27     1000
# 46       1000_46      0.0   2018-06-30     1000
# 67       1000_67      0.0   2018-06-16     1000
# 72       1000_72      0.0   2018-06-15     1000
# ...          ...      ...          ...      ...
# 149380  1499_141      0.0   2018-12-11     1499
# 149381  1499_142      0.0   2018-11-01     1499
# 149383  1499_144      0.0   2018-11-27     1499
# 149386  1499_147      0.0   2018-10-21     1499
# 149393  1499_154      0.0   2018-10-27     1499
#
# [19598 rows x 4 columns]

# %%
print('Количество сессий 0 мб :' ,internet[internet['mb_used'] == 0].shape[0])
# Out:
# Количество сессий 0 мб : 19598

# %% [markdown]
# По всей видимости это сбои интернет-сессий.

# %%
internet['mb_used'] = internet['mb_used'].replace(0, np.NaN) # заменим 0 на NaN

# %%
internet.plot(y = 'mb_used', kind = 'hist', bins = 50, grid=True, figsize = (6,6), range=(min_range_mb_used,max_range_mb_used))
plt.plot()
plt.title("Использование интернет-трафика", fontsize=12, fontweight="bold")
plt.xlabel("объём потраченного за сессию интернет-трафика (в мегабайтах)", fontsize=12, fontweight="bold")
plt.ylabel("сессий", fontsize=12, fontweight="bold")
# Out:
# Text(0, 0.5, 'сессий')

# %% [markdown]
# ### Таблица `tariffs` (информация о тарифах)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
qw = tariffs
print('----------------------------------------------------ГОЛОВА')
display(qw.head())
print('----------------------------------------------------СТАТИСТИКА')
display(qw.describe().round(2))
print('----------------------------------------------------ИНФО')
display(qw.info())
print('----------------------------------------------------РАНДОМ')
display(qw.sample(2))
print('----------------------------------------------------ДУБЛИКАТЫ')
print('Дубликатов по calls:', qw.duplicated().sum())
# Out:
# ----------------------------------------------------ГОЛОВА
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
# ----------------------------------------------------СТАТИСТИКА
#        messages_included  mb_per_month_included  minutes_included  \
# count               2.00                   2.00              2.00
# mean              525.00               23040.00           1750.00
# std               671.75               10861.16           1767.77
# min                50.00               15360.00            500.00
# 25%               287.50               19200.00           1125.00
# ...

# %% [markdown]
# Ошибок нет

# %% [markdown]
# ### Добавление столбца месяц в DF-ы

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
# выведем данные для наглядности
for i in [users, calls, messages, internet]:
    display(i.head())
# Out:
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra
#        id  call_date  duration  user_id
# 0  1000_0 2018-07-25       NaN     1000
# 1  1000_1 2018-08-17       NaN     1000
# 2  1000_2 2018-06-11       3.0     1000
# 3  1000_3 2018-09-21      14.0     1000
# 4  1000_4 2018-12-15       6.0     1000
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000
# ...

# %% [markdown]
# Добавим месяца в наши DF

# %%
users['month_column'] = users['reg_date'].dt.month.astype('int')
calls['month_column'] = calls['call_date'].dt.month.astype('int')
messages['month_column'] = messages['message_date'].dt.month.astype('int')
internet['month_column'] = internet['session_date'].dt.month.astype('int')

# %% [markdown]
# Проверим изменения

# %%
for i in [users, calls, messages, internet]:
    display(i.head())
# Out:
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff  month_column
# 0  ultra             5
# 1  smart            11
# 2  smart             6
# 3  ultra             8
# 4  ultra             5
#        id  call_date  duration  user_id  month_column
# 0  1000_0 2018-07-25       NaN     1000             7
# 1  1000_1 2018-08-17       NaN     1000             8
# 2  1000_2 2018-06-11       3.0     1000             6
# 3  1000_3 2018-09-21      14.0     1000             9
# 4  1000_4 2018-12-15       6.0     1000            12
#        id message_date  user_id  month_column
# ...

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 5 columns):
# id              202607 non-null object
# call_date       202607 non-null datetime64[ns]
# duration        162994 non-null float64
# user_id         202607 non-null int64
# month_column    202607 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 7.7+ MB

# %%
# напишем функцию добавления рус.месяцев

def rus_momth(x):
    '''функция рус_мес'''
    if x == 1:
        return 'Январь'
    if x == 2:
        return 'Февраль'
    if x == 3:
        return 'Март'
    if x == 4:
        return 'Апрель'
    if x == 5:
        return 'Май'
    if x == 6:
        return 'Июнь'
    if x == 7:
        return 'Июль'
    if x == 8:
        return 'Август'
    if x == 9:
        return 'Сентябрь'
    if x == 10:
        return 'Октябрь'
    if x == 11:
        return 'Ноябрь'
    if x == 12:
        return 'Декабрь'

# %%
# применим функцию через цикл к кадому df

for i in [users, calls, messages, internet]: # берем каждый df из списка
    # в этот df добавляем столбец rus_month_column
    # а данные для него берем из столбца month_column и применеям к нему функ rus_momth
    i['rus_month_column'] = i['month_column'].apply(rus_momth)

# %% [markdown]
# Взглянем на результат

# %%
for i in [users, calls, messages, internet]:
    display(i.head())
# Out:
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff  month_column rus_month_column
# 0  ultra             5              Май
# 1  smart            11           Ноябрь
# 2  smart             6             Июнь
# 3  ultra             8           Август
# 4  ultra             5              Май
#        id  call_date  duration  user_id  month_column rus_month_column
# 0  1000_0 2018-07-25       NaN     1000             7             Июль
# 1  1000_1 2018-08-17       NaN     1000             8           Август
# 2  1000_2 2018-06-11       3.0     1000             6             Июнь
# ...

# %% [markdown]
# ### Количество звонков и израсходованных минут разговора, объем интернета по месяцам

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Обьединим таблицы `calls` `messages` `internet` с `users`, сохранив их в отдельные переменные

# %%
calls_users = calls.merge(users[['user_id', 'tariff', 'city', 'age', 'first_name', 'last_name']], on = 'user_id', how = 'outer')
calls_users['month_column'] = calls_users['month_column'].astype('Int64') # меняем тип данных для месяца
calls_users['duration'] = calls_users['duration'].astype('Int64')

# %%
messages_users = messages.merge(users[['user_id', 'tariff', 'city', 'age', 'first_name', 'last_name']], on = 'user_id', how = 'outer')
messages_users['month_column'] = messages_users['month_column'].astype('Int64')

# %%
internet_users = internet.merge(users[['user_id', 'tariff', 'city', 'age', 'first_name', 'last_name']], on = 'user_id', how = 'outer')
internet_users['month_column'] = internet_users['month_column'].astype('Int64')

# %% [markdown]
# Посмотрим звонки

# %%
calls_users_pivot_table = calls_users.pivot_table(index = 'month_column', values = 'duration', aggfunc=['count', 'sum'])
calls_users_pivot_table.plot(y = ['count','sum'],figsize = (15,5), grid = True, kind = 'bar')
# обозначим названия осей и таблички
plt.xlabel('Месяц',fontsize = 15, fontweight="bold")
plt.ylabel('кол-во звонков/минут',fontsize = 15, fontweight="bold")
plt.title('Количество звонков и минут по месяцам',fontsize = 20, fontweight="bold")
#calls_users_pivot_table
# Out:
# Text(0.5, 1.0, 'Количество звонков и минут по месяцам')

# %% [markdown]
# Посмотрим сообщения

# %%
messages_users_pivot_table = messages_users.pivot_table(index = 'month_column', values = 'user_id', aggfunc=['count'])
messages_users_pivot_table.plot(y = ['count'],figsize = (15,5), grid = True, kind = 'bar')

plt.xlabel('Месяц',fontsize = 15, fontweight="bold")
plt.ylabel('кол-во сообщений',fontsize = 15, fontweight="bold")
plt.title('Количество сообщений по месяцам',fontsize = 20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Количество сообщений по месяцам')

# %% [markdown]
# Посмотрим интернет

# %%
internet_users_pivot_table = internet_users.pivot_table(index = 'month_column', values = 'mb_used', aggfunc=['sum'])

internet_users_pivot_table.plot(y = ['sum'],figsize = (15,5), grid = True, kind = 'bar')
plt.xlabel('Месяц',fontsize = 15, fontweight="bold")
plt.ylabel('кол-во трафика',fontsize = 15, fontweight="bold")
plt.title('Количество трафика по месяцам',fontsize = 20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Количество трафика по месяцам')

# %%
calls_users.pivot_table(index = 'tariff', values = 'duration', aggfunc=['count', 'sum']).plot(
    kind = 'pie', subplots=True, legend = 'tariff',
    autopct='%.2f', figsize=(10,5), shadow=True, fontsize=20)
plt.title("Доля звонков и израсходаванных минут разговора %",fontsize = 15, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Доля звонков и израсходаванных минут разговора %')

# %%
messages_users.pivot_table(index = 'tariff', values = 'user_id', aggfunc=['count']).plot(
    kind = 'pie', subplots=True, legend = 'tariff',
    autopct='%.2f', figsize=(10,5), shadow=True, fontsize=20)
plt.title("Доля использования сообщений на тарифах %",fontsize = 15, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Доля использования сообщений на тарифах %')

# %%
internet_users.pivot_table(index = 'tariff', values = 'mb_used', aggfunc=['sum']).plot(
    kind = 'pie', subplots=True, legend = 'tariff',
    autopct='%.2f', figsize=(10,5), shadow=True, fontsize=20)
plt.title("Доля использования интернета на тарифах %",fontsize = 15, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Доля использования интернета на тарифах %')

# %% [markdown]
# Количество регистраций пользователей на тарифы `smart` и `ultra`

# %%
users.pivot_table(index = 'tariff', values = 'user_id', aggfunc=['count']).plot(
    kind = 'pie', subplots=True, legend = 'tariff',
    autopct='%.2f', figsize=(10,5), shadow=True, fontsize=20)
plt.title("Доля клиентов подключившихся к услугам Мегалайн %",fontsize = 15, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Доля клиентов подключившихся к услугам Мегалайн %')

# %%
z = users.pivot_table(index=['month_column'], values='user_id', aggfunc=('count'))
q = users.query('tariff == "ultra"').pivot_table(index=['month_column'], values='user_id', aggfunc=('count'))
w = users.query('tariff == "smart"').pivot_table(index=['month_column'], values='user_id', aggfunc=('count'))
#x = np.array(range(0,12))
x = ['янв','фев','мар','апр','май','июн','июл','авг','сен','окт','ноя','дек']
plt.figure(figsize=(13,8))
plt.plot(x, z, linestyle="-", marker="o", label="всего подключений")
plt.plot(x, w, linestyle="-", marker="o", label="smart")
plt.plot(x, q, linestyle="-", marker="o", label="ultra")
plt.title("Подключение пользователей к Мегалайну за 12 месяцев",fontsize = 15, fontweight="bold")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Как видим, больше всего подключенией к тарифу `smart`, на нем 70.2% пользователей

# %% [markdown]
# ## Объединим данные, посчитаем помесячную выручку

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
# calls_users message_users internet_users

# %%
# группируем данные по звонкам
calls_users_1 = calls_users.groupby(['user_id','month_column','tariff','city'])['duration'].agg(['count','sum'])
calls_users_1
# Out:
#                                          count  sum
# user_id month_column tariff city
# 1000    5            ultra  Краснодар       17  159
#         6            ultra  Краснодар       28  172
#         7            ultra  Краснодар       41  340
#         8            ultra  Краснодар       42  408
#         9            ultra  Краснодар       46  466
# ...                                        ...  ...
# 1498    10           smart  Владикавказ     30  247
# 1499    9            smart  Пермь            8   70
#         10           smart  Пермь           44  449
#         11           smart  Пермь           62  612
#         12           smart  Пермь           56  492
#
# [3174 rows x 2 columns]

# %%
# группируем данные по сообщениям
messages_users_1 = messages_users.groupby(['user_id','month_column','tariff','city'])['user_id'].agg(['count'])
messages_users_1
# Out:
#                                          count
# user_id month_column tariff city
# 1000    5            ultra  Краснодар       22
#         6            ultra  Краснодар       60
#         7            ultra  Краснодар       75
#         8            ultra  Краснодар       81
#         9            ultra  Краснодар       57
# ...                                        ...
# 1498    10           smart  Владикавказ     42
# 1499    9            smart  Пермь           11
#         10           smart  Пермь           48
#         11           smart  Пермь           59
#         12           smart  Пермь           66
#
# [2717 rows x 1 columns]

# %%
# группируем данные по интернету
internet_users_1 = internet_users.groupby(['user_id','month_column','tariff','city']).sum()['mb_used']
internet_users_1
# Out:
# user_id  month_column  tariff  city
# 1000     5             ultra   Краснодар       2253.49
#          6             ultra   Краснодар      23233.77
#          7             ultra   Краснодар      14003.64
#          8             ultra   Краснодар      14055.93
#          9             ultra   Краснодар      14568.91
#                                                 ...
# 1498     10            smart   Владикавказ    20579.36
# 1499     9             smart   Пермь           1845.75
#          10            smart   Пермь          17788.51
#          11            smart   Пермь          17963.31
#          12            smart   Пермь          13055.58
# Name: mb_used, Length: 3203, dtype: float64

# %%
#результат одинаков
#internet_users_2 = internet_users.groupby(['user_id','month_column','tariff','city'])['mb_used'].sum()
#internet_users_2

# %%
# обьединяем данные в один df
df_cal_mes_int = pd.concat([calls_users_1, messages_users_1, internet_users_1], axis = 1)

# %%
df_cal_mes_int
# Out:
#                                          count  sum  count   mb_used
# user_id month_column tariff city
# 1000    5            ultra  Краснодар     17.0  159   22.0   2253.49
#         6            ultra  Краснодар     28.0  172   60.0  23233.77
#         7            ultra  Краснодар     41.0  340   75.0  14003.64
#         8            ultra  Краснодар     42.0  408   81.0  14055.93
#         9            ultra  Краснодар     46.0  466   57.0  14568.91
# ...                                        ...  ...    ...       ...
# 1498    10           smart  Владикавказ   30.0  247   42.0  20579.36
# 1499    9            smart  Пермь          8.0   70   11.0   1845.75
#         10           smart  Пермь         44.0  449   48.0  17788.51
#         11           smart  Пермь         62.0  612   59.0  17963.31
#         12           smart  Пермь         56.0  492   66.0  13055.58
#
# [3214 rows x 4 columns]

# %%
# обновляем индексы
df_cal_mes_int = df_cal_mes_int.reset_index()

# %%
df_cal_mes_int
# Out:
#       user_id  month_column tariff         city  count  sum  count   mb_used
# 0        1000             5  ultra    Краснодар   17.0  159   22.0   2253.49
# 1        1000             6  ultra    Краснодар   28.0  172   60.0  23233.77
# 2        1000             7  ultra    Краснодар   41.0  340   75.0  14003.64
# 3        1000             8  ultra    Краснодар   42.0  408   81.0  14055.93
# 4        1000             9  ultra    Краснодар   46.0  466   57.0  14568.91
# ...       ...           ...    ...          ...    ...  ...    ...       ...
# 3209     1498            10  smart  Владикавказ   30.0  247   42.0  20579.36
# 3210     1499             9  smart        Пермь    8.0   70   11.0   1845.75
# 3211     1499            10  smart        Пермь   44.0  449   48.0  17788.51
# 3212     1499            11  smart        Пермь   62.0  612   59.0  17963.31
# 3213     1499            12  smart        Пермь   56.0  492   66.0  13055.58
#
# [3214 rows x 8 columns]

# %% [markdown]
# Переименуем столбцы

# %%
df_cal_mes_int.columns = ['user_id', 'месяц', 'тариф', 'город', 'кол_звонков',
                         'звонки_мин', 'смс_шт', 'интернет_Мб']

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар         17.0         159    22.0
# 1        1000      6  ultra    Краснодар         28.0         172    60.0
# 2        1000      7  ultra    Краснодар         41.0         340    75.0
# 3        1000      8  ultra    Краснодар         42.0         408    81.0
# 4        1000      9  ultra    Краснодар         46.0         466    57.0
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ         30.0         247    42.0
# 3210     1499      9  smart        Пермь          8.0          70    11.0
# 3211     1499     10  smart        Пермь         44.0         449    48.0
# 3212     1499     11  smart        Пермь         62.0         612    59.0
# 3213     1499     12  smart        Пермь         56.0         492    66.0
#
#       интернет_Мб
# 0         2253.49
# 1        23233.77
# 2        14003.64
# ...

# %% [markdown]
# Отсортируем

# %%
df_cal_mes_int.sort_values(by = ['user_id', 'месяц']).head(12)
# Out:
#     user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0      1000      5  ultra    Краснодар         17.0         159    22.0
# 1      1000      6  ultra    Краснодар         28.0         172    60.0
# 2      1000      7  ultra    Краснодар         41.0         340    75.0
# 3      1000      8  ultra    Краснодар         42.0         408    81.0
# 4      1000      9  ultra    Краснодар         46.0         466    57.0
# 5      1000     10  ultra    Краснодар         44.0         350    73.0
# 6      1000     11  ultra    Краснодар         37.0         338    58.0
# 7      1000     12  ultra    Краснодар         38.0         333    70.0
# 8      1001     11  smart       Москва         45.0         430     NaN
# 9      1001     12  smart       Москва         47.0         414     NaN
# 10     1002      6  smart  Стерлитамак         14.0         117     4.0
# 11     1002      7  smart  Стерлитамак         21.0         214    11.0
#
#     интернет_Мб
# ...

# %%
df_cal_mes_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3214 entries, 0 to 3213
# Data columns (total 8 columns):
# user_id        3214 non-null int64
# месяц          3214 non-null int64
# тариф          3214 non-null object
# город          3214 non-null object
# кол_звонков    3174 non-null float64
# звонки_мин     3174 non-null Int64
# смс_шт         2717 non-null float64
# интернет_Мб    3203 non-null float64
# dtypes: Int64(1), float64(3), int64(2), object(2)
# memory usage: 204.1+ KB

# %% [markdown]
# Проверим данные на наличие пропусков (звонки, смс, интернет), далее выберем рандомных пользователей по user_id, чтоб посмотреть в чем дело?!

# %%
df_cal_mes_int[df_cal_mes_int['интернет_Мб'].isna()]
# Out:
#       user_id  месяц  тариф      город  кол_звонков  звонки_мин  смс_шт  \
# 1722     1273      5  ultra     Курган         19.0         220    21.0
# 1723     1273      6  ultra     Курган         28.0         230    38.0
# 1724     1273      7  ultra     Курган         30.0         253    37.0
# 1725     1273      8  ultra     Курган         39.0         253    41.0
# 1726     1273      9  ultra     Курган         28.0         223    32.0
# 1727     1273     10  ultra     Курган         35.0         315    35.0
# 1728     1273     11  ultra     Курган         31.0         272    29.0
# 1729     1273     12  ultra     Курган         38.0         260    39.0
# 2387     1377      2  ultra     Брянск         20.0         179     2.0
# 2500     1392      2  ultra  Челябинск          2.0          13     3.0
# 2858     1446      8  smart     Липецк          4.0          50     1.0
#
#       интернет_Мб
# 1722          NaN
# 1723          NaN
# 1724          NaN
# 1725          NaN
# ...

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1392] # первый месяц подключения, пользователь не успел воспользоваться интернетом
# Out:
#       user_id  месяц  тариф      город  кол_звонков  звонки_мин  смс_шт  \
# 2500     1392      2  ultra  Челябинск          2.0          13     3.0
# 2501     1392      3  ultra  Челябинск         54.0         467    38.0
# 2502     1392      4  ultra  Челябинск         54.0         436    33.0
# 2503     1392      5  ultra  Челябинск         35.0         364    36.0
# 2504     1392      6  ultra  Челябинск         53.0         415    49.0
# 2505     1392      7  ultra  Челябинск         58.0         452    37.0
# 2506     1392      8  ultra  Челябинск         47.0         496    32.0
# 2507     1392      9  ultra  Челябинск         43.0         377    38.0
#
#       интернет_Мб
# 2500          NaN
# 2501     22977.99
# 2502     14865.73
# 2503     15723.08
# 2504     19660.38
# 2505     22221.61
# 2506     15774.90
# 2507     21730.26

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1377] # так же видим первый меяц
# Out:
#       user_id  месяц  тариф   город  кол_звонков  звонки_мин  смс_шт  \
# 2387     1377      2  ultra  Брянск         20.0         179     2.0
# 2388     1377      3  ultra  Брянск        165.0        1609    20.0
# 2389     1377      4  ultra  Брянск        121.0        1096    17.0
# 2390     1377      5  ultra  Брянск        125.0        1097    16.0
# 2391     1377      6  ultra  Брянск        141.0        1290    15.0
# 2392     1377      7  ultra  Брянск        144.0        1311    13.0
# 2393     1377      8  ultra  Брянск        143.0        1273    11.0
# 2394     1377      9  ultra  Брянск        141.0        1297    17.0
# 2395     1377     10  ultra  Брянск        148.0        1401    10.0
# 2396     1377     11  ultra  Брянск        129.0        1161    16.0
# 2397     1377     12  ultra  Брянск        147.0        1259    17.0
#
#       интернет_Мб
# 2387          NaN
# 2388      3059.85
# 2389      1151.05
# 2390      6608.89
# 2391      4717.58
# 2392      4205.46
# ...

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1446] # все один в один
# Out:
#       user_id  месяц  тариф   город  кол_звонков  звонки_мин  смс_шт  \
# 2858     1446      8  smart  Липецк          4.0          50     1.0
# 2859     1446      9  smart  Липецк         45.0         421    38.0
# 2860     1446     10  smart  Липецк         39.0         289    31.0
# 2861     1446     11  smart  Липецк         68.0         642    32.0
# 2862     1446     12  smart  Липецк         45.0         424    43.0
#
#       интернет_Мб
# 2858          NaN
# 2859     20262.46
# 2860     14123.88
# 2861     16318.67
# 2862     17989.07

# %% [markdown]
# Правильным решением будет заменить пропуски на 0

# %% [markdown]
# Посмотрим СМС

# %%
df_cal_mes_int[df_cal_mes_int['смс_шт'].isna()] # выберем рандомные user_id и првоерим ниже
# Out:
#       user_id  месяц  тариф      город  кол_звонков  звонки_мин  смс_шт  \
# 8        1001     11  smart     Москва         45.0         430     NaN
# 9        1001     12  smart     Москва         47.0         414     NaN
# 42       1006      2  smart  Ульяновск          3.0          42     NaN
# 43       1006      3  smart  Ульяновск         36.0         286     NaN
# 44       1006      4  smart  Ульяновск         38.0         356     NaN
# ...       ...    ...    ...        ...          ...         ...     ...
# 3181     1494      8  smart       Омск         26.0         262     NaN
# 3182     1494      9  smart       Омск         57.0         501     NaN
# 3183     1494     10  smart       Омск         45.0         354     NaN
# 3184     1494     11  smart       Омск         46.0         411     NaN
# 3185     1494     12  smart       Омск         54.0         418     NaN
#
#       интернет_Мб
# 8        18429.34
# 9        14036.66
# 42        1392.15
# 43       17287.93
# ...

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1001] # не пользовался
# Out:
#    user_id  месяц  тариф   город  кол_звонков  звонки_мин  смс_шт  интернет_Мб
# 8     1001     11  smart  Москва         45.0         430     NaN     18429.34
# 9     1001     12  smart  Москва         47.0         414     NaN     14036.66

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1006] # не пользовался весь год и это вполне естественно, из личного опыта
# Out:
#     user_id  месяц  тариф      город  кол_звонков  звонки_мин  смс_шт  \
# 42     1006      2  smart  Ульяновск          3.0          42     NaN
# 43     1006      3  smart  Ульяновск         36.0         286     NaN
# 44     1006      4  smart  Ульяновск         38.0         356     NaN
# 45     1006      5  smart  Ульяновск         45.0         370     NaN
# 46     1006      6  smart  Ульяновск         48.0         478     NaN
# 47     1006      7  smart  Ульяновск         38.0         316     NaN
# 48     1006      8  smart  Ульяновск         32.0         275     NaN
# 49     1006      9  smart  Ульяновск         47.0         360     NaN
# 50     1006     10  smart  Ульяновск         35.0         267     NaN
# 51     1006     11  smart  Ульяновск         46.0         372     NaN
# 52     1006     12  smart  Ульяновск         44.0         379     NaN
#
#     интернет_Мб
# 42      1392.15
# 43     17287.93
# 44     13936.70
# 45     12965.41
# 46     12371.66
# 47     19977.60
# ...

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1494] # так же не пользовался
# Out:
#       user_id  месяц  тариф город  кол_звонков  звонки_мин  смс_шт  \
# 3181     1494      8  smart  Омск         26.0         262     NaN
# 3182     1494      9  smart  Омск         57.0         501     NaN
# 3183     1494     10  smart  Омск         45.0         354     NaN
# 3184     1494     11  smart  Омск         46.0         411     NaN
# 3185     1494     12  smart  Омск         54.0         418     NaN
#
#       интернет_Мб
# 3181      6590.75
# 3182     16962.51
# 3183     17767.24
# 3184     18052.45
# 3185     17621.21

# %% [markdown]
# Принимаем решение заменить NaN на 0, смс изживает себя как средство связи среди пользователей

# %% [markdown]
# Посмотрим ЗВОНКИ

# %%
df_cal_mes_int[df_cal_mes_int['звонки_мин'].isna()] # выберем рандомные user_id и првоерим ниже
# Out:
#       user_id  месяц  тариф             город  кол_звонков  звонки_мин  \
# 570      1091      5  ultra  Набережные Челны          NaN         NaN
# 571      1091      6  ultra  Набережные Челны          NaN         NaN
# 572      1091      7  ultra  Набережные Челны          NaN         NaN
# 573      1091      8  ultra  Набережные Челны          NaN         NaN
# 574      1091      9  ultra  Набережные Челны          NaN         NaN
# 575      1091     10  ultra  Набережные Челны          NaN         NaN
# 576      1091     11  ultra  Набережные Челны          NaN         NaN
# 577      1091     12  ultra  Набережные Челны          NaN         NaN
# 671      1106      4  ultra            Калуга          NaN         NaN
# 672      1106      5  ultra            Калуга          NaN         NaN
# 673      1106      6  ultra            Калуга          NaN         NaN
# 674      1106      7  ultra            Калуга          NaN         NaN
# ...

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1091] # не пользовался звонками
# Out:
#      user_id  месяц  тариф             город  кол_звонков  звонки_мин  смс_шт  \
# 570     1091      5  ultra  Набережные Челны          NaN         NaN    30.0
# 571     1091      6  ultra  Набережные Челны          NaN         NaN    30.0
# 572     1091      7  ultra  Набережные Челны          NaN         NaN    35.0
# 573     1091      8  ultra  Набережные Челны          NaN         NaN    31.0
# 574     1091      9  ultra  Набережные Челны          NaN         NaN    32.0
# 575     1091     10  ultra  Набережные Челны          NaN         NaN    44.0
# 576     1091     11  ultra  Набережные Челны          NaN         NaN    28.0
# 577     1091     12  ultra  Набережные Челны          NaN         NaN    42.0
#
#      интернет_Мб
# 570     10703.37
# 571     10236.19
# 572     16444.98
# 573     12633.88
# 574     16597.11
# 575     15644.73
# 576     11864.25
# 577     13280.45

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1106] # не пользовался звонками
# Out:
#      user_id  месяц  тариф   город  кол_звонков  звонки_мин  смс_шт  \
# 671     1106      4  ultra  Калуга          NaN         NaN     9.0
# 672     1106      5  ultra  Калуга          NaN         NaN    28.0
# 673     1106      6  ultra  Калуга          NaN         NaN    30.0
# 674     1106      7  ultra  Калуга          NaN         NaN    24.0
# 675     1106      8  ultra  Калуга          NaN         NaN    25.0
# 676     1106      9  ultra  Калуга          NaN         NaN    23.0
# 677     1106     10  ultra  Калуга          NaN         NaN    33.0
# 678     1106     11  ultra  Калуга          NaN         NaN    29.0
# 679     1106     12  ultra  Калуга          NaN         NaN    24.0
#
#      интернет_Мб
# 671      2923.49
# 672     16573.01
# 673     20016.74
# 674     21626.86
# 675     19088.67
# 676     21934.03
# 677     14010.32
# 678     21289.27
# 679     18701.51

# %%
df_cal_mes_int[df_cal_mes_int['user_id'] == 1489] # не пользовался звонками
# Out:
#       user_id  месяц  тариф            город  кол_звонков  звонки_мин  смс_шт  \
# 3149     1489      8  smart  Санкт-Петербург          NaN         NaN    17.0
# 3150     1489      9  smart  Санкт-Петербург          NaN         NaN    32.0
# 3151     1489     10  smart  Санкт-Петербург          NaN         NaN    21.0
# 3152     1489     11  smart  Санкт-Петербург          NaN         NaN    20.0
# 3153     1489     12  smart  Санкт-Петербург          NaN         NaN    35.0
#
#       интернет_Мб
# 3149     11050.56
# 3150     17206.30
# 3151     19559.44
# 3152     17491.56
# 3153     17322.51

# %% [markdown]
# Принимаем решение заменить пропуски на 0, пользователи не пользовались звонками и активно пользовались интернетом
# Сейчас очень актуальны звонки по Whatsapp Telegram

# %% [markdown]
# Меняем пропуски по СМС, звонкам и интренет на 0.

# %%
df_cal_mes_int['кол_звонков'] = df_cal_mes_int['кол_звонков'].fillna(0).astype('Int64')
df_cal_mes_int['смс_шт'] = df_cal_mes_int['смс_шт'].fillna(0).astype('Int64')
df_cal_mes_int['интернет_Мб'] = df_cal_mes_int['интернет_Мб'].fillna(0)#.astype(np.int64, errors='ignore')

# %% [markdown]
# Посмотрим данные

# %%
df_cal_mes_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3214 entries, 0 to 3213
# Data columns (total 8 columns):
# user_id        3214 non-null int64
# месяц          3214 non-null int64
# тариф          3214 non-null object
# город          3214 non-null object
# кол_звонков    3214 non-null Int64
# звонки_мин     3174 non-null Int64
# смс_шт         3214 non-null Int64
# интернет_Мб    3214 non-null float64
# dtypes: Int64(3), float64(1), int64(2), object(2)
# memory usage: 210.4+ KB

# %%
z = df_cal_mes_int.pivot_table(index=['месяц'], values='user_id', aggfunc=('count'))
q = df_cal_mes_int.query('тариф == "ultra"').pivot_table(index=['месяц'], values='user_id', aggfunc=('count'))
w = df_cal_mes_int.query('тариф == "smart"').pivot_table(index=['месяц'], values='user_id', aggfunc=('count'))
x = np.array(range(12))

plt.figure(figsize=(13,8))
plt.plot(x, z, linestyle="-", marker="o", label="всего использований услуг Мегалайн")
plt.plot(x, w, linestyle="-", marker="o", label="smart")
plt.plot(x, q, linestyle="-", marker="o", label="ultra")
plt.title("Частота использования тарифов за 12 месяцев",fontsize = 15, fontweight="bold")
plt.legend()
plt.show()

# %%
all_users = df_cal_mes_int['user_id'].count()


def func_pct(pct):
    value = float(pct/100.*all_users)
    return "{:.2f}%\n({:.0f} чел.)".format(pct, value)

explode = (0.05, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['user_id'].count().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     title = 'Распределение по клиентам', pctdistance=0.45,
                                                                     figsize=(20,5), autopct=lambda pct: func_pct(pct))

plt.tight_layout(pad=0)

for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# Взглянем на тарифы

# %%
tariffs
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %% [markdown]
# Изменим порядок столбцов

# %%
tariffs = tariffs.reindex(columns=['tariff_name','messages_included','mb_per_month_included','minutes_included','rub_monthly_fee','rub_per_gb', 'rub_per_message', 'rub_per_minute'])
tariffs
# Out:
#   tariff_name  messages_included  mb_per_month_included  minutes_included  \
# 0       smart                 50                  15360               500
# 1       ultra               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute
# 0              550         200                3               3
# 1             1950         150                1               1

# %% [markdown]
# Переименуем стобцы

# %%
tariffs.columns = ['тариф', 'кол_смс_вк_абплт', 'объ_инт_вк_абплт_mb', 'кол_мин_вк_абплт', 'аб_плт','1гб_сверх_тп', '1смс_сверх_тп', '1мин_сверх_тп']

# %%
tariffs
# Out:
#    тариф  кол_смс_вк_абплт  объ_инт_вк_абплт_mb  кол_мин_вк_абплт  аб_плт  \
# 0  smart                50                15360               500     550
# 1  ultra              1000                30720              3000    1950
#
#    1гб_сверх_тп  1смс_сверх_тп  1мин_сверх_тп
# 0           200              3              3
# 1           150              1              1

# %%
df_cal_mes_int = df_cal_mes_int.merge(tariffs, on = 'тариф', how='outer')
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Мб  кол_смс_вк_абплт  объ_инт_вк_абплт_mb  кол_мин_вк_абплт  \
# ...

# %%
# Удалить значения если меньше 0
# exp_by_pay_period['Gb_extra'] = np.where(exp_by_pay_period['Gb_extra']<0, 0, exp_by_pay_period['Gb_extra'])

# %% [markdown]
# Переведем **Mb** в **Gb**

# %%
df_cal_mes_int['интернет_Мб'] = (df_cal_mes_int['интернет_Мб']/1024).apply(np.ceil).astype('Int64')
df_cal_mes_int['объ_инт_вк_абплт_mb'] = (df_cal_mes_int['объ_инт_вк_абплт_mb']/1024).apply(np.ceil).astype('Int64')

# %% [markdown]
# Переименуем столбцы в **Гб**

# %%
df_cal_mes_int = df_cal_mes_int.rename(columns={'интернет_Мб': 'интернет_Гб', 'объ_инт_вк_абплт_mb': 'объ_инт_вк_абплт_Гб'})

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  кол_мин_вк_абплт  \
# ...

# %% [markdown]
# ### Перерасход звонков. Вычтем бесплатный лимит из суммарного количества звонков

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
df_cal_mes_int['перерасход_звонков_мин'] = df_cal_mes_int['звонки_мин']-df_cal_mes_int['кол_мин_вк_абплт']

# %% [markdown]
# Уберем значения меньше 0, отрицательные

# %%
df_cal_mes_int['перерасход_звонков_мин'] = np.where(df_cal_mes_int['перерасход_звонков_мин']<0, 0, df_cal_mes_int['перерасход_звонков_мин'])

# %% [markdown]
# Изменим тип данных

# %%
df_cal_mes_int['перерасход_звонков_мин'] = df_cal_mes_int['перерасход_звонков_мин'].astype('Int64')

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  кол_мин_вк_абплт  \
# ...

# %% [markdown]
# ### Перерасход смс. Вычтем лимит соощений

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
df_cal_mes_int['перерасход_смс'] = df_cal_mes_int['смс_шт']-df_cal_mes_int['кол_смс_вк_абплт']

# %% [markdown]
# Уберем значения меньше 0, отрицательные

# %%
df_cal_mes_int['перерасход_смс'] = np.where(df_cal_mes_int['перерасход_смс']<0, 0, df_cal_mes_int['перерасход_смс'])

# %%
df_cal_mes_int['перерасход_смс'] = df_cal_mes_int['перерасход_смс'].astype('Int64')

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  кол_мин_вк_абплт  \
# ...

# %% [markdown]
# ### Перерасход интернет-трафика. Вычтем лимит трафика

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
df_cal_mes_int['перерасход_Гб'] = df_cal_mes_int['интернет_Гб']-df_cal_mes_int['объ_инт_вк_абплт_Гб']

# %% [markdown]
# Уберем значения меньше 0, отрицательные

# %%
df_cal_mes_int['перерасход_Гб'] = np.where(df_cal_mes_int['перерасход_Гб']<0, 0, df_cal_mes_int['перерасход_Гб'])

# %%
df_cal_mes_int['перерасход_Гб'] = df_cal_mes_int['перерасход_Гб'].astype('Int64')

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  кол_мин_вк_абплт  \
# ...

# %% [markdown]
# ### Выручка (сборка)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# #### Выручка за перерасход звонков

# %%
df_cal_mes_int['выр_перерасход_звонков_мин'] = df_cal_mes_int['перерасход_звонков_мин']*df_cal_mes_int['1мин_сверх_тп']

# %%
df_cal_mes_int['выр_перерасход_звонков_мин'] = np.where(df_cal_mes_int['выр_перерасход_звонков_мин']<0, 0, df_cal_mes_int['выр_перерасход_звонков_мин'])

# %%
df_cal_mes_int['выр_перерасход_звонков_мин'] = df_cal_mes_int['выр_перерасход_звонков_мин'].astype('Int64')

# %%
df_cal_mes_int['выр_перерасход_звонков_мин'].sum()
# Out:
# 278217

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  кол_мин_вк_абплт  \
# ...

# %% [markdown]
# #### Выручка за перерасход смс

# %%
df_cal_mes_int['выр_перерасход_смс'] = df_cal_mes_int['перерасход_смс']*df_cal_mes_int['1смс_сверх_тп']

# %%
df_cal_mes_int['выр_перерасход_смс'] = np.where(df_cal_mes_int['выр_перерасход_смс']<0, 0, df_cal_mes_int['выр_перерасход_смс'])

# %%
df_cal_mes_int['выр_перерасход_смс'] = df_cal_mes_int['выр_перерасход_смс'].astype('Int64')

# %%
df_cal_mes_int['выр_перерасход_смс'].sum()
# Out:
# 38784

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  кол_мин_вк_абплт  \
# ...

# %% [markdown]
# #### Выручка за перерасход Гб

# %%
df_cal_mes_int['выр_перерасход_Гб'] = df_cal_mes_int['перерасход_Гб']*df_cal_mes_int['1гб_сверх_тп']

# %%
df_cal_mes_int['выр_перерасход_Гб'] = np.where(df_cal_mes_int['выр_перерасход_Гб']<0, 0, df_cal_mes_int['выр_перерасход_Гб'])

# %%
df_cal_mes_int['выр_перерасход_Гб'] = df_cal_mes_int['выр_перерасход_Гб'].astype('Int64')

# %%
df_cal_mes_int['выр_перерасход_Гб'].sum()
# Out:
# 1450750

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  ...  аб_плт  \
# ...

# %% [markdown]
# Заменим `NaN` в столбцах с выручкой на 0

# %%
df_cal_mes_int['выр_перерасход_звонков_мин'] = df_cal_mes_int['выр_перерасход_звонков_мин'].fillna(0)
df_cal_mes_int['выр_перерасход_смс'] = df_cal_mes_int['выр_перерасход_смс'].fillna(0)
df_cal_mes_int['выр_перерасход_Гб'] = df_cal_mes_int['выр_перерасход_Гб'].fillna(0)
df_cal_mes_int['аб_плт'] = df_cal_mes_int['аб_плт'].fillna(0)

# %% [markdown]
# #### Общая выручка

# %% [markdown]
# Посчитаем общую выручку за перерасход Гб, СМС, МИН, + стоимость тарифа

# %%
# соберем все суммы вместе
itog_sum = 0
for i in ['выр_перерасход_звонков_мин','выр_перерасход_смс','выр_перерасход_Гб','аб_плт']:
    print(df_cal_mes_int[i].sum(), "----" ,i)
    itog_sum += df_cal_mes_int[i].sum()
print(itog_sum, 'Всего выручка')
# Out:
# 278217 ---- выр_перерасход_звонков_мин
# 38784 ---- выр_перерасход_смс
# 1450750 ---- выр_перерасход_Гб
# 3146700 ---- аб_плт
# 4914451 Всего выручка

# %% [markdown]
# Обьединим столбцы с выручками

# %%
df_cal_mes_int['итого_выручка'] = df_cal_mes_int['аб_плт']+df_cal_mes_int['выр_перерасход_звонков_мин']+df_cal_mes_int['выр_перерасход_смс']+df_cal_mes_int['выр_перерасход_Гб']

# %% [markdown]
# Результат общей выручки после объединения столбцов

# %%
proverka_revenue = df_cal_mes_int['итого_выручка'].sum()
proverka_revenue
# Out:
# 4914451

# %%
if itog_sum == proverka_revenue:
    print('ИТОГОВАЯ ВЫРУЧКА СОШЛАСЬ ++++++')
else:
    print('ОШИБКА итоговой выручки -----')
# Out:
# ИТОГОВАЯ ВЫРУЧКА СОШЛАСЬ ++++++

# %%
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  ...  1гб_сверх_тп  \
# ...

# %%
df_cal_mes_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 0 to 3213
# Data columns (total 22 columns):
# user_id                       3214 non-null int64
# месяц                         3214 non-null int64
# тариф                         3214 non-null object
# город                         3214 non-null object
# кол_звонков                   3214 non-null Int64
# звонки_мин                    3174 non-null Int64
# смс_шт                        3214 non-null Int64
# интернет_Гб                   3214 non-null Int64
# кол_смс_вк_абплт              3214 non-null int64
# объ_инт_вк_абплт_Гб           3214 non-null Int64
# кол_мин_вк_абплт              3214 non-null int64
# аб_плт                        3214 non-null int64
# 1гб_сверх_тп                  3214 non-null int64
# 1смс_сверх_тп                 3214 non-null int64
# 1мин_сверх_тп                 3214 non-null int64
# перерасход_звонков_мин        3174 non-null Int64
# перерасход_смс                3214 non-null Int64
# ...

# %% [markdown]
# ### Выручка по месяцам

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
revenue_month = df_cal_mes_int.pivot_table(index = 'месяц', values = 'итого_выручка', aggfunc=['sum'])
revenue_month.plot(y = ['sum'],figsize = (15,5), grid = True, kind = 'bar')
# обозначим названия осей и таблички
plt.xlabel('Месяц',fontsize = 15, fontweight="bold")
plt.ylabel('Сумма выручки',fontsize = 15, fontweight="bold")
plt.title('Сумма выручки по месяцам',fontsize = 20, fontweight="bold")
#calls_users_pivot_table
# Out:
# Text(0.5, 1.0, 'Сумма выручки по месяцам')

# %% [markdown]
# Распределение выручки по тарифам

# %%
q = df_cal_mes_int.query('тариф == "ultra"').pivot_table(index=['месяц'], values='итого_выручка', aggfunc=('sum'))
w = df_cal_mes_int.query('тариф == "smart"').pivot_table(index=['месяц'], values='итого_выручка', aggfunc=('sum'))
#x = np.array(range(0,12))
x = ['янв','фев','мар','апр','май','июн','июл','авг','сен','окт','ноя','дек']
plt.figure(figsize=(13,8))
#plt.plot(x, z, linestyle="-", marker="o", label="всего подключений")
plt.plot(x, w, linestyle="-", marker="o", label="smart")
plt.plot(x, q, linestyle="-", marker="o", label="ultra")
plt.title("Сумма выручки по месяцам на тарифах smart и ultra",fontsize = 15, fontweight="bold")
plt.xlabel("месяцы", fontsize=12, fontweight="bold")
plt.ylabel('выручка',fontsize = 15, fontweight="bold")
plt.grid()
plt.legend()
plt.show()

# %%
df_cal_mes_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 0 to 3213
# Data columns (total 22 columns):
# user_id                       3214 non-null int64
# месяц                         3214 non-null int64
# тариф                         3214 non-null object
# город                         3214 non-null object
# кол_звонков                   3214 non-null Int64
# звонки_мин                    3174 non-null Int64
# смс_шт                        3214 non-null Int64
# интернет_Гб                   3214 non-null Int64
# кол_смс_вк_абплт              3214 non-null int64
# объ_инт_вк_абплт_Гб           3214 non-null Int64
# кол_мин_вк_абплт              3214 non-null int64
# аб_плт                        3214 non-null int64
# 1гб_сверх_тп                  3214 non-null int64
# 1смс_сверх_тп                 3214 non-null int64
# 1мин_сверх_тп                 3214 non-null int64
# перерасход_звонков_мин        3174 non-null Int64
# перерасход_смс                3214 non-null Int64
# ...

# %%
bar_color1 = '#CCCC33'
bar_color2 = '#CC9900'
bar_color3 = '#0066FF'
bar_color4 = '#33CCFF'

# set plot style: grey grid in the background: стиль графика
sns.set(style="darkgrid")

# set the figure size размер
plt.figure(figsize=(14, 7))

# top bar -> sum all values to find y position of the bars группировка по всех данных месяц и итого_выручка
total = df_cal_mes_int.groupby('месяц')['итого_выручка'].sum().reset_index()
# bar chart 1 -> top bars строим столбцы по группировке total
bar1 = sns.barplot(x="месяц",  y="итого_выручка", data=total, color=bar_color1)


# bar chart 3 -> bottom bars (group of Ultra) группировка по всех данных месяц и аб_плт
total2 = df_cal_mes_int.groupby('месяц')['аб_плт'].sum().reset_index()
# строим столбцы по группировке total 2
bar2 = sns.barplot(x="месяц", y="аб_плт", data=total2, estimator=sum, ci=None,  color=bar_color2)


# bottom bar ->  take only Ultra строим график по тарифу ultra
ultra = df_cal_mes_int[df_cal_mes_int.тариф=='ultra']

# bar chart 2 -> bottom bars (group of Ultra) группируем график по тарифу месяцу и итого_выручка
bar3 = sns.barplot(x="месяц", y="итого_выручка", data=ultra, estimator=sum, ci=None,  color=bar_color3)

# bar chart 3 -> bottom bars (group of Ultra)
ultra2 = df_cal_mes_int[df_cal_mes_int.тариф=='ultra'] # группируем по ultra
bar4 = sns.barplot(x="месяц", y="аб_плт", data=ultra2, estimator=sum, ci=None,  color=bar_color4)

# add legend опишем легенды
bar1 = mpatches.Patch(color=bar_color1, label='Smart - платежи сверх тарифа')
bar2 = mpatches.Patch(color=bar_color2, label='Smart - абон. плата')
bar3 = mpatches.Patch(color=bar_color3, label='Ultra - платежи сверх тарифа')
bar4 = mpatches.Patch(color=bar_color4, label='Ultra - абон. плата')
plt.legend(handles=[bar1, bar2, bar3, bar4])
plt.title("Выручка общая",fontsize = 15, fontweight="bold")
plt.xlabel('Месяц',fontsize = 12, fontweight="bold")
plt.ylabel('руб.',fontsize = 12, fontweight="bold")
# показать график
plt.show()

# %% [markdown]
# ### Распределение выручки в зависимости от тарифа

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
all_revenue = df_cal_mes_int['итого_выручка'].sum()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} руб.)".format(pct, value)

explode = (0.05, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['итого_выручка'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,7),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("Распределение выручки по тарифам",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.2, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
df_cal_mes_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 0 to 3213
# Data columns (total 22 columns):
# user_id                       3214 non-null int64
# месяц                         3214 non-null int64
# тариф                         3214 non-null object
# город                         3214 non-null object
# кол_звонков                   3214 non-null Int64
# звонки_мин                    3174 non-null Int64
# смс_шт                        3214 non-null Int64
# интернет_Гб                   3214 non-null Int64
# кол_смс_вк_абплт              3214 non-null int64
# объ_инт_вк_абплт_Гб           3214 non-null Int64
# кол_мин_вк_абплт              3214 non-null int64
# аб_плт                        3214 non-null int64
# 1гб_сверх_тп                  3214 non-null int64
# 1смс_сверх_тп                 3214 non-null int64
# 1мин_сверх_тп                 3214 non-null int64
# перерасход_звонков_мин        3174 non-null Int64
# перерасход_смс                3214 non-null Int64
# ...

# %% [markdown]
# ### Распределение услуг по клиентам

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
all_revenue = df_cal_mes_int['user_id'].count()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} руб.)".format(pct, value)

explode = (0.07, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['user_id'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("Распределение услуг по клиентам",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# Почти 70 % клиентов пользуются услугами тарифа `smart`

# %% [markdown]
# ### Активность использования услуг smart и ultra в разбивке: звонки, смс, интернет

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Посмотрим на частоту использования услуг в разбивке на звонки, смс и интренет, среди пользователей

# %%
columns_to_plot = ['звонки_мин', 'смс_шт', 'интернет_Гб']

calls_sum = df_cal_mes_int['звонки_мин'].sum()
sms_sum = df_cal_mes_int['смс_шт'].sum()
internet_sum = df_cal_mes_int['интернет_Гб'].sum()

def func_pct(pct):
    if pct > 65 or pct < 35:
        sum_of_data = internet_sum
        value = float(pct/100.*sum_of_data)
        metric = 'Гб'
    elif pct > 64 or pct < 36:
        sum_of_data = calls_sum
        value = float(pct/100.*sum_of_data)
        metric = 'мин.'
    else:
        sum_of_data = sms_sum
        value = float(pct/100.*sum_of_data)
        metric = 'шт.'
    return "{:.2f}%\n({:.0f} {})".format(pct, value, metric)

explode = (0.2, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')[columns_to_plot].sum().plot(kind='pie', subplots=True, fontsize=20,
                                                                       use_index=False, shadow=True, explode=explode,
                                                                       title = columns_to_plot, pctdistance=0.45,
                                                                       autopct=lambda pct: func_pct(pct), figsize=(20,10))
plt.text(-6.5, 1.8, "Активность использования услуг smart и ultra в разбивке: звонки, смс, интернет за год", fontsize=20,fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], framealpha=0.2, bbox_to_anchor=(0.87,0.87), prop={'size':15})
    ax.set_ylabel('')

# %% [markdown]
# Лидерство по использованию СМС интренет и звонкамм, оставляем за собой `smart`

# %% [markdown]
# ## Дозаказ услуг всего и в разбивке

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Услуги, которые чаще всего дозаказывают

# %%
 df_cal_mes_int.groupby('тариф')[columns_to_plot].sum()
# Out:
#        звонки_мин  смс_шт  интернет_Гб
# тариф
# smart      931577   74413        36397
# ultra      518724   48623        19202

# %% [markdown]
# ### Интернет-трафик

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Посмотрим сколько потребовалось Гб интренета сверх лимита за год

# %%
all_revenue = df_cal_mes_int['перерасход_Гб'].sum()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} Гб сверх)".format(pct, value)

explode = (0.07, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['перерасход_Гб'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("ИНТЕРНЕТ Потребовалость Гб сверх пакета всего за год",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# Сколько необходимо интернета в среднем `mean`

# %%
all_revenue = df_cal_mes_int['перерасход_Гб'].mean()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.2f} Гб сверх)".format(pct, value)

explode = (0.07, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['перерасход_Гб'].mean().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("ИНТЕРНЕТ Требуется Гб сверх пакета в среднем",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# ### Звонки

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Взглянем на кол-во минут сверх лимита в год

# %%
all_revenue = df_cal_mes_int['перерасход_звонков_мин'].sum()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} мин.сверх)".format(pct, value)

explode = (0.07, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['перерасход_звонков_мин'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("ЗВОНКИ Потребовалость минут сверх пакета всего за год",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# У пользоватлей `ultra` нет потребностей в дополнительных минутах разговора

# %% [markdown]
# Псомотрим на среднее `mean`

# %%
all_revenue = df_cal_mes_int['перерасход_звонков_мин'].mean()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} мин.сверх)".format(pct, value)

explode = (0.07, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['перерасход_звонков_мин'].mean().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))

plt.title("ЗВОНКИ Требуется минут сверх пакета в среднем",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# В среднем, пользователям тарифа `smart` необходимо 30 минут дополнительных минут в месяц

# %%
 df_cal_mes_int.groupby('тариф')[columns_to_plot].sum()
# Out:
#        звонки_мин  смс_шт  интернет_Гб
# тариф
# smart      931577   74413        36397
# ultra      518724   48623        19202

# %% [markdown]
# ### СМС

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Ну и посмотрим на СМС

# %%
all_revenue = df_cal_mes_int['перерасход_смс'].sum()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} смс.сверх)".format(pct, value)

explode = (0.07, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['перерасход_смс'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("Потребовалость СМС сверх пакета всего за год",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# Как и в случае со сзвонками, дополнительные СМС сверх пакета нужны только пользователям тарифа `smart`

# %% [markdown]
# Взглянем на среднее кол-во СМС сверх тарифного плана

# %%
all_revenue = df_cal_mes_int['перерасход_смс'].mean()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} смс.сверх)".format(pct, value)

explode = (0.07, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['перерасход_смс'].mean().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))

plt.title("требуется СМС сверх пакета в среднем",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# Всего 5 СМС в среднем

# %% [markdown]
# ### Выручка сверх тарифа

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Посчитаем выручку сверх тарифного плана. Добавим новый столбец с выручками по сверх лимитам

# %%
# соберем все суммы вместе - без абонентской платы
itog_sum_sv = 0
for i in ['выр_перерасход_звонков_мин','выр_перерасход_смс','выр_перерасход_Гб']:
    print(df_cal_mes_int[i].sum(), "----" ,i)
    itog_sum_sv += df_cal_mes_int[i].sum()
print(itog_sum_sv, 'Всего выручка')
# Out:
# 278217 ---- выр_перерасход_звонков_мин
# 38784 ---- выр_перерасход_смс
# 1450750 ---- выр_перерасход_Гб
# 1767751 Всего выручка

# %%
df_cal_mes_int['выручка_сверх'] = df_cal_mes_int['выр_перерасход_звонков_мин']+df_cal_mes_int['выр_перерасход_смс']+df_cal_mes_int['выр_перерасход_Гб']

# %%
df_cal_mes_int['выручка_сверх'] = df_cal_mes_int['выручка_сверх'].fillna(0)

# %%
proverka_revenue_sv = df_cal_mes_int['выручка_сверх'].sum()
proverka_revenue_sv
# Out:
# 1767751

# %%
if itog_sum_sv == proverka_revenue_sv:
    print('ВЫРУЧКА ПО ЛИМИТАМ СОШЛАСЬ ++++++')
else:
    print('ОШИБКА ЛИМИТНОЙ выручки -----')
# Out:
# ВЫРУЧКА ПО ЛИМИТАМ СОШЛАСЬ ++++++

# %%
all_revenue = df_cal_mes_int['выручка_сверх'].sum()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} )".format(pct, value)

explode = (0.2, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.groupby('тариф')['выручка_сверх'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("Выручка сверх тарифного плана в год",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.5, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# Добавим столбец с группировкой: сверх такрифа и в рамках тарифа

# %%
# напишем функцию прописывающую признак переплаты
def expense_signd(row): # назовем функцию, на вход будем подавать 1 значение
    '''функция - переплаты'''
    kat = row['выручка_сверх']           
    try:                               
        if kat > 0:                 
            return 'Сверх тарифа'            
        elif kat == 0:    
            return 'В рамках тарифа'                        
    except:                            
        return 'что-то пошло не так'

# %%
# добавим стобец, применим функцию
df_cal_mes_int['категория_переплаты'] = df_cal_mes_int.apply(expense_signd, axis = 1)

# %%
df_cal_mes_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 0 to 3213
# Data columns (total 24 columns):
# user_id                       3214 non-null int64
# месяц                         3214 non-null int64
# тариф                         3214 non-null object
# город                         3214 non-null object
# кол_звонков                   3214 non-null Int64
# звонки_мин                    3174 non-null Int64
# смс_шт                        3214 non-null Int64
# интернет_Гб                   3214 non-null Int64
# кол_смс_вк_абплт              3214 non-null int64
# объ_инт_вк_абплт_Гб           3214 non-null Int64
# кол_мин_вк_абплт              3214 non-null int64
# аб_плт                        3214 non-null int64
# 1гб_сверх_тп                  3214 non-null int64
# 1смс_сверх_тп                 3214 non-null int64
# 1мин_сверх_тп                 3214 non-null int64
# перерасход_звонков_мин        3174 non-null Int64
# перерасход_смс                3214 non-null Int64
# ...

# %% [markdown]
# ### Количество пользователей сверх тарифа (распределение по `ultra` и `smart`)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
all_revenue = df_cal_mes_int.query('тариф == "ultra"').pivot_table(index = ['тариф', 'категория_переплаты'], values = ['выручка_сверх'], aggfunc=['count']).sum()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} чел.)".format(pct, value)

explode = (0.2, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.query('тариф == "ultra"').pivot_table(index = ['тариф', 'категория_переплаты'], values = ['выручка_сверх'], aggfunc=['count']).plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     title = '', pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("Количество пользователей ultra",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Переплата', 'В рамках тарифа'], bbox_to_anchor=(0.12,0.15), framealpha=0.12, prop={'size':16})
    ax.set_ylabel('')

# %%
all_revenue = df_cal_mes_int.query('тариф == "smart"').pivot_table(index = ['тариф', 'категория_переплаты'], values = ['выручка_сверх'], aggfunc=['count']).sum()
def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} чел.)".format(pct, value)

explode = (0.2, 0)  # сектор 'ultra' немного выдвинем

axes = df_cal_mes_int.query('тариф == "smart"').pivot_table(index = ['тариф', 'категория_переплаты'], values = ['выручка_сверх'], aggfunc=['count']).plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     title = '', pctdistance=0.45,
                                                                     startangle=20, figsize=(20,6),
                                                                     autopct=lambda pct: func_pct(pct))
plt.title("Количество пользователей smart",fontsize = 15, fontweight="bold")
for ax in axes:
    ax.legend(['Переплата', 'В рамках тарифа'], bbox_to_anchor=(0.12,0.87), framealpha=0.12, prop={'size':16})
    ax.set_ylabel('')

# %% [markdown]
# ### Общая информация

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Сделаем сборку данных для наглядности, чтоб все в одном месте

# %%
col = ['звонки_мин', 'смс_шт',
       'интернет_Гб', 'перерасход_Гб', 'перерасход_звонков_мин', 'перерасход_смс', 'аб_плт',
       'выр_перерасход_Гб', 'выр_перерасход_звонков_мин', 'выр_перерасход_смс','выручка_сверх', 'итого_выручка']

full_info = pd.concat([df_cal_mes_int[list(col)].sum(), 
                       df_cal_mes_int[list(col)].mean(), 
                       df_cal_mes_int.query('тариф == "ultra"')[list(col)].sum(),
                      df_cal_mes_int.query('тариф == "ultra"')[list(col)].mean(),
                       df_cal_mes_int.query('тариф == "smart"')[list(col)].sum(),
                      df_cal_mes_int.query('тариф == "smart"')[list(col)].mean(),
                      df_cal_mes_int.query('тариф == "ultra"')[list(col)].count(),
                      df_cal_mes_int.query('тариф == "smart"')[list(col)].count()], axis = 1).round(1)

full_info.columns = ['сумма', 'среднее','ultra_сумма','ultra_среднее','smart_сумма', 'smart_среднее','ultra_колич','smart_колич']

full_info
# Out:
#                                 сумма  среднее  ultra_сумма  ultra_среднее  \
# звонки_мин                  1450301.0    456.9     518724.0          545.5
# смс_шт                       123036.0     38.3      48623.0           49.4
# интернет_Гб                   55599.0     17.3      19202.0           19.5
# перерасход_Гб                  7451.0      2.3        789.0            0.8
# перерасход_звонков_мин        92739.0     29.2          0.0            0.0
# перерасход_смс                12928.0      4.0          0.0            0.0
# аб_плт                      3146700.0    979.1    1920750.0         1950.0
# выр_перерасход_Гб           1450750.0    451.4     118350.0          120.2
# выр_перерасход_звонков_мин   278217.0     86.6          0.0            0.0
# выр_перерасход_смс            38784.0     12.1          0.0            0.0
# выручка_сверх               1767751.0    550.0     118350.0          120.2
# ...

# %% [markdown]
# Активно переплачивают сверх пакета только абоненты тарифа `smart` по всем услугам без исключений, в то время как пользователи тарифа `ultra` вылазят за пределы услуг интернета

# %% [markdown]
# ### Гистограммы переплат

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Построим Гистограммы переплат значение range поставим условные, для `smart` 200:1000 и `ultra` 150:2000

# %%
spisok_1 = ['выручка_сверх'] # список столбцов на вывод
spisok_2 = ['smart', 'ultra'] # список условий на вывод
col_sps = max([int(len(spisok_2)),int(len(spisok_1))]) # находим max значение из 2 списков, чтоб знать кол-во итераций цикла
counter = 0 # счетчик итераций
tarif_range = {'smart':(200, 1000), 'ultra':(150, 2000)} # условия для range Поиск по ключу
for i in spisok_1:
    counter += 1
    try:
        if counter <= col_sps: 
            for j in spisok_2:
                plot = df_cal_mes_int[(df_cal_mes_int['тариф'] == j) & (df_cal_mes_int[i] > 0)][i]
                plot.plot(y = i, grid=True,  kind = 'hist', figsize = (12,8), bins=50, range = tarif_range.get(j))
                plt.title(j + " "+ i ,fontsize = 15, fontweight="bold")
                plt.show()
                
    except:
        print('Что-то сломалось', i, j)
    # выводим plot

# %% [markdown]
# По гистограмме `smart` видим большую часть клиентов  c переплатой кратной 200 руб.,
# дозаказывают 1 Гб интернета согласно тарифу 200р. По гистограмме `ultra` видим большую часть клиентов
# c переплатой кратной 150 руб.,
# дозаказывают 1 Гб интернета согласно тарифу 150.

# %% [markdown]
# ### Медиана, cреднее, дисперсия, стандартнное отклонение по набору данных

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Информация о выбросах по набору данных (boxplot)

# %%
# перед рассчетами избавимся от NaN ибо ящик с усами (который будем строить) ругулся 
df_cal_mes_int['смс_шт'] = df_cal_mes_int['смс_шт'].fillna(0)
df_cal_mes_int['интернет_Гб'] = df_cal_mes_int['интернет_Гб'].fillna(0)
df_cal_mes_int['кол_звонков'] = df_cal_mes_int['кол_звонков'].fillna(0)

# %%
q_1 = df_cal_mes_int[['user_id', 'тариф', 'звонки_мин']]
pd.set_option('chained_assignment', None) # скрывает предупреждения
q_2 = df_cal_mes_int[['user_id', 'тариф', 'смс_шт']]
q_3 = df_cal_mes_int[['user_id', 'тариф', 'интернет_Гб']]
df_q=q_1.append(q_2).append(q_3)

spisok_1 = ['звонки_мин', 'смс_шт', 'интернет_Гб'] # список с столбцами на вывод
for i in spisok_1:
    plt.figure(figsize=(10,10)) # ВАЖНО !!!! этот блок должен быть до sns.boxplotplt.figure(figsize=(25,20)) до sns.boxplot()
    sns.boxplot(x='тариф', y= i, data=df_q)
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %% [markdown]
# ### Гистограммы распределения по набору данных: звонкам, смс, интернет

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
spisok_1 = ['звонки_мин','смс_шт','интернет_Гб'] # список столбцов на вывод
spisok_2 = ['smart', 'ultra'] # список условий на вывод
col_sps = max([int(len(spisok_2)),int(len(spisok_1))]) # находим max значение из 2 списков, чтоб знать кол-во итераций цикла
counter = 0 # счетчик итераций
tarif_range_min = {'smart':(0, 1000), 'ultra':(0, 2000)} # условия для range Поиск по ключу
tarif_range_sms = {'smart':(0, 200), 'ultra':(0, 300)} # условия для range Поиск по ключу
tarif_range_gb = {'smart':(0, 50), 'ultra':(0, 60)} # условия для range Поиск по ключу
for i in spisok_1:
    counter += 1
    try:
        if counter <= col_sps: 
            for j in spisok_2:
                if i == 'звонки_мин':                 
                    plot = df_cal_mes_int[(df_cal_mes_int['тариф'] == j) & (df_cal_mes_int[i] > 0)][i]
                    plot.plot(y = i, grid=True,  kind = 'hist', figsize = (12,8), bins=50, range = tarif_range_min.get(j))
                    plt.title(j +" "+ i ,fontsize = 15, fontweight="bold")
                    plt.show()
                if i == 'смс_шт':
                    plot = df_cal_mes_int[(df_cal_mes_int['тариф'] == j) & (df_cal_mes_int[i] > 0)][i]
                    plot.plot(y = i, grid=True,  kind = 'hist', figsize = (12,8), bins=50, range = tarif_range_sms.get(j))
                    plt.title(j +" "+ i ,fontsize = 15, fontweight="bold")
                    plt.show()
                if i == 'интернет_Гб':
                    plot = df_cal_mes_int[(df_cal_mes_int['тариф'] == j) & (df_cal_mes_int[i] > 0)][i]
                    plot.plot(y = i, grid=True,  kind = 'hist', figsize = (12,8), bins=50, range = tarif_range_gb.get(j))
                    plt.title(j +" "+ i ,fontsize = 15, fontweight="bold")
                    plt.show()
                    
    except:
        print('Что-то сломалось', i, j)
    # выводим plot

# %% [markdown]
# Медиана, cреднее, дисперсия, стандартнное отклонение `median`,`mean`,`var`,`std`

# %%
spisok_3 = ['смс_шт', 'интернет_Гб','звонки_мин','итого_выручка','выручка_сверх']
for i in spisok_3:
    display(df_cal_mes_int.groupby('тариф').agg({i:['median','mean','var','std']}).style.format("{:.1f}"))
# Out:
# <style  type="text/css" >
# </style><table id="T_02a9b27e_7885_11ec_a7b1_02420a3971a4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4>смс_шт</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >median</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >var</th>        <th class="col_heading level1 col3" >std</th>    </tr>    <tr>        <th class="index_name level0" >тариф</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_02a9b27e_7885_11ec_a7b1_02420a3971a4level0_row0" class="row_heading level0 row0" >smart</th>
#                         <td id="T_02a9b27e_7885_11ec_a7b1_02420a3971a4row0_col0" class="data row0 col0" >28.0</td>
# ...

# %% [markdown]
# **СМС:** клиенты `smart` используют в среднем до 30 и укладываются в рамки пакета 50 смс, тогда как в `ultra` почти 40 смс в среднем, но с пакетом 1000 смс в месяц - переплата пользователям ultra не страшна
#
# **Звонки** клиенты `smart` используют в среднем 419 минут, причем медиана 423 мин., пользователи тарифа полностю выбирают количество минут включенных в пакет и часть из них переплачивает за минуты сверх лимита, в `ultra` среднее 545 минут и разброс до 800 минут, а в пакете 3000 минут в мес, так же нет переплат
#
# **Интернет:** клиенты `smart` используют в среднем  16.4 Гб, а медиана 17 Гб, что превышает лимит
# в 15 ГБ и приводи к необходимости дозаказывать дополнительные пакеты данных,
# тогда как в `ultra` среднее 19,5 что списывается в рамки пакета услуг, который составляет 30Гб
#
# **Выручка за превышение лимита** здесь лидируют пользователи тарифа smart, что не удивительно, так как выбирают лимиты и переплачивают за превышение, а вот пользователи ultra практически не дозаказывают данные, только Гб, поэтому среднее значение 121
#
# **Выручка общая** среднее значение выше у тарифа `ultra` это обьяснимо стоимотью абонентской платы, она в 3 раза больше, чем у пользователей `smart`, но не забываем про общий обьем выручки максимальная доля принадлежит тарифу `smart` - все дело в количестве пользователей

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# * средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются;
# * средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.
# Пороговое значение alpha задайте самостоятельно.
#
# **Поясните:**
# * как вы формулировали нулевую и альтернативную гипотезы;
# * какой критерий использовали для проверки гипотез и почему.

# %%
# перед рассчетами избавимся от NaN ибо ящик с усами (который будем строить) ругулся 
#df_cal_mes_int['смс_шт'] = df_cal_mes_int['смс_шт'].fillna(0)
#df_cal_mes_int['интернет_Гб'] = df_cal_mes_int['интернет_Гб'].fillna(0)
#df_cal_mes_int['кол_звонков'] = df_cal_mes_int['кол_звонков'].fillna(0)
#df_cal_mes_int['аб_плт'] = df_cal_mes_int['аб_плт'].fillna(0)

# %%
# ТОЖЕ РАБОЧИЙ ВАРИАНТ
#upper_quartile = np.percentile(df_cal_mes_int['выручка_сверх'], 75)
#lower_quartile = np.percentile(df_cal_mes_int['выручка_сверх'], 25)
# подготавливаем ящик с усами
#iqr = upper_quartile - lower_quartile
#upper_whisker = df_cal_mes_int['выручка_сверх'][df_cal_mes_int['выручка_сверх']<=upper_quartile+1.5*iqr].max()
#lower_whisker = df_cal_mes_int['выручка_сверх'][df_cal_mes_int['выручка_сверх']>=lower_quartile-1.5*iqr].min()

#spisok_1 = ['выручка_сверх'] # список с столбцами на вывод
#for i in spisok_1:
    
#    df_cal_mes_int.boxplot(column = i, by = 'тариф',
#                           figsize=(8,9), fontsize = 10,
#                           whiskerprops=dict(linestyle='-', linewidth=5),
#                           capprops=dict(linestyle='-', linewidth=5),
#                           medianprops=dict(linestyle='-', linewidth=5))
#plt.ylim(lower_whisker*0.5, upper_whisker*1.5)

# %%
q_1 = df_cal_mes_int[['user_id', 'тариф', 'выручка_сверх']]
pd.set_option('chained_assignment', None) # скрывает предупреждения
q_2 = df_cal_mes_int[['user_id', 'тариф', 'итого_выручка']]
#q_3 = df_cal_mes_int[['user_id', 'тариф', 'итого_выручка']]
df_q=q_1.append(q_2)#.append(q_3)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
# ВАЖНО !!!! блок plt.figure(figsize=(10,10)) должен быть до sns.boxplot()
# и включить, %matplotlib inline добавили к загрузке библиотек
spisok_1 = ['выручка_сверх', 'итого_выручка'] # список с столбцами на вывод
for i in spisok_1:
    plt.figure(figsize=(10,10)) # ВАЖНО !!!! этот блок должен быть до sns.boxplotplt.figure(figsize=(25,20)) до sns.boxplot()
    sns.boxplot(x='тариф', y= i, data=df_q)
    plt.show()

# %% [markdown]
# Границы интервала для столбца `smart` 0-3500
# Границы интервала для столбца `ultra` 1950-1950

# %%
# Напишем функцию для удаления выбросов

def delete_outliers(df, column, graphic=0, x = 10, y = 10):
    q1 = df[column].quantile(0.25)                 
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    iqr_test = (df[column] >= (q1 - 1.5 * iqr)) & (df[column] <= (q3 + 1.5 * iqr))
    if graphic == 1:
        return df.loc[iqr_test].boxplot([column], figsize=(x,y))
    else:
        return df.loc[iqr_test]

# %% [markdown]
# Используем t-критерий Стьюдента, ибо выборки независимы между собой тарифы разные

# %% [markdown]
# ### Гипотеза о равенстве сосвокупностей №1

# %% [markdown]
# **Гипотезы:**
#
# * H0 выручка пользователей тарифов `smart` и `ultra` не различаются
# * H1 выручка пользователей тарифов `smart` и `ultra` различаются

# %% [markdown]
# Сформируем БД

# %%
ultra = df_cal_mes_int[df_cal_mes_int['тариф'] == 'ultra']
smart = df_cal_mes_int[df_cal_mes_int['тариф'] == 'smart']

# %% [markdown]
# Приеним функцию, удалим выбросы

# %%
ultra = delete_outliers(ultra, 'итого_выручка', 0)
ultra = ultra['итого_выручка']

# %%
smart = delete_outliers(smart, 'итого_выручка', 0)
smart = smart['итого_выручка']

# %%
alpha = 0.05 # пороговое значение

# %%
results = st.ttest_ind(ultra, smart)

# %%
ultra_mean = df_cal_mes_int[df_cal_mes_int['тариф'] == 'ultra'].groupby('user_id')['итого_выручка'].mean().mean().round()

# %%
smart_mean = df_cal_mes_int[df_cal_mes_int['тариф'] == 'smart'].groupby('user_id')['итого_выручка'].mean().mean().round()

# %%
difference1 = abs(ultra_mean-smart_mean)

# %%
print('t-значение:', results.statistic)
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
    
print('Средняя выручка по ultra ', ultra_mean)
print('Средняя выручка по smart ', smart_mean)
print('Разница средних ', difference1)
# Out:
# t-значение: 28.125319854630078
# p-значение: 6.199325734928115e-155
# Отвергаем нулевую гипотезу
# Средняя выручка по ultra  2086.0
# Средняя выручка по smart  1324.0
# Разница средних  762.0

# %% [markdown]
# Разница в виду отличий между выборками

# %% [markdown]
# ### Гипотеза о равенстве двух средних генеральных совокупностях №2

# %% [markdown]
# **Гипотезы:**
#
# *  H0 средняя выручка пользователей из Москвы НЕ ОТЛИЧАЕТСЯ от выручка пользователей других регионов
# *  H1 средняя выручка пользователей из Москвы ОТЛИЧАЕТСЯ от выручка пользователей других регионов

# %% [markdown]
# Взглянем на список городов

# %%
df_cal_mes_int['город'].unique()
# Out:
# array(['Краснодар', 'Москва', 'Новокузнецк', 'Иваново', 'Омск', 'Уфа',
#        'Томск', 'Санкт-Петербург', 'Тверь', 'Ярославль', 'Тюмень',
#        'Ростов-на-Дону', 'Калуга', 'Тула', 'Волгоград', 'Саранск',
#        'Иркутск', 'Череповец', 'Набережные Челны', 'Новосибирск',
#        'Брянск', 'Тольятти', 'Нижний Тагил', 'Воронеж', 'Махачкала',
#        'Пермь', 'Сургут', 'Пенза', 'Мурманск', 'Самара',
#        'Нижний Новгород', 'Кемерово', 'Кострома', 'Оренбург', 'Чебоксары',
#        'Магнитогорск', 'Астрахань', 'Нижневартовск', 'Челябинск',
#        'Курган', 'Красноярск', 'Владивосток', 'Смоленск', 'Владимир',
#        'Казань', 'Саратов', 'Севастополь', 'Рязань', 'Екатеринбург',
#        'Стерлитамак', 'Ульяновск', 'Балашиха', 'Барнаул', 'Киров', 'Сочи',
#        'Вологда', 'Чита', 'Петрозаводск', 'Хабаровск', 'Ставрополь',
#        'Улан-Удэ', 'Курск', 'Якутск', 'Химки', 'Владикавказ', 'Ижевск',
#        'Орёл', 'Белгород', 'Архангельск', 'Липецк', 'Волжский', 'Тамбов',
# ...

# %%
# создадим новый столбец в df
# воспользуемся np.where

df_cal_mes_int['регион'] = np.where(df_cal_mes_int['город'] == 'Москва', 'Москва', 'Другие')

# %%
# проверим
df_cal_mes_int
# Out:
#       user_id  месяц  тариф        город  кол_звонков  звонки_мин  смс_шт  \
# 0        1000      5  ultra    Краснодар           17         159      22
# 1        1000      6  ultra    Краснодар           28         172      60
# 2        1000      7  ultra    Краснодар           41         340      75
# 3        1000      8  ultra    Краснодар           42         408      81
# 4        1000      9  ultra    Краснодар           46         466      57
# ...       ...    ...    ...          ...          ...         ...     ...
# 3209     1498     10  smart  Владикавказ           30         247      42
# 3210     1499      9  smart        Пермь            8          70      11
# 3211     1499     10  smart        Пермь           44         449      48
# 3212     1499     11  smart        Пермь           62         612      59
# 3213     1499     12  smart        Пермь           56         492      66
#
#       интернет_Гб  кол_смс_вк_абплт  объ_инт_вк_абплт_Гб  ...  \
# ...

# %%
moscow = df_cal_mes_int[df_cal_mes_int['регион'] == 'Москва']
other = df_cal_mes_int[df_cal_mes_int['регион'] == 'Другие']

# %%
moscow = delete_outliers(moscow, 'итого_выручка', 0)
moscow = moscow['итого_выручка']

# %%
other = delete_outliers(other, 'итого_выручка', 0)
other = other['итого_выручка']

# %%
results = st.ttest_ind(moscow, other)
# equal_var = False

# %%
#Среднее по Москве
revenue_msk_mean = df_cal_mes_int[df_cal_mes_int['регион'] == 'Москва'].groupby('user_id')['итого_выручка'].mean().mean().round()

# %%
#Среднее по Другим
revenue_other_mean = df_cal_mes_int[df_cal_mes_int['регион'] == 'Другие'].groupby('user_id')['итого_выручка'].mean().mean().round()

# %%
# разница
difference = abs(revenue_msk_mean-revenue_other_mean)

# %%
print('t-значение:', results.statistic)
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
    
print('Средняя выручка по Москве ', revenue_msk_mean)
print('Средняя выручка по Другим ', revenue_other_mean)
print('Разница средних ', difference)
# Out:
# t-значение: 1.0494681372676922
# p-значение: 0.29404256281786245
# Не получилось отвергнуть нулевую гипотезу
# Средняя выручка по Москве  1498.0
# Средняя выручка по Другим  1564.0
# Разница средних  66.0

# %% [markdown]
# Нулевую гипотезу отвергуть не получается, хотя разница не критична

# %% [markdown]
# *  Опровергли гипотезу, H0 выручка пользователей тарифов smart и ultra не различаются
#
# *  Не опровергли гипотезу, H0 средняя выручка пользователей из Москвы НЕ ОТЛИЧАЕТСЯ от выручки пользователей других регионов

# %% [markdown]
# ## Обший вывод

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Основная масса пользователей подключены к тарифу Ультра

# %% [markdown]
# Что в свою очередь влияет на распределение услуг Мегалайна по клиентам в ввиду количественного превосходства, тариф Смарт лидирует по всем категориям: СМС, ЗВОНКИ, ИНТЕРНЕТ.
#
# В течении года было использовано услуг в следующем объеме:

# %% [markdown]
# Так как условия в пакетах Смарт и Ультра разные, это отражается на объёмах дополнительных услуг.

# %% [markdown]
# Количество пользователей воспользовавшихся дополнительным объемом услуг компании

# %% [markdown]
# **СМС:** клиенты smart используют в среднем до 30 и укладываются в рамки пакета 50 смс, тогда как в ultra почти 40 смс в среднем, но с пакетом 1000 смс в месяц - переплата пользователям ultra не страшна
#
# **Звонки:** клиенты smart используют в среднем 419 минут, причем медиана 423 мин., пользователи тарифа полностю выбирают количество минут включенных в пакет и часть из них переплачивает за минуты сверх лимита, в ultra среднее 545 минут и разброс до 800 минут, а в пакете 3000 минут в мес, так же нет переплат
#
# **Интернет:** клиенты smart используют в среднем 16.4 Гб, а медиана 17 Гб, что превышает лимит
# в 15 ГБ и приводи к необходимости дозаказывать дополнительные пакеты данных,
# тогда как в ultra среднее 19,5 что списывается в рамки пакета услуг, который составляет 30Гб
#
# **Выручка за превышение лимита** здесь лидируют пользователи тарифа smart, что не удивительно, так как выбирают лимиты и переплачивают за превышение, а вот пользователи ultra практически не дозаказывают данные, только Гб, поэтому среднее значение 121
#
# **Выручка общая среднее значение** выше у тарифа ultra это обьяснимо стоимотью абонентской платы, она в 3 раза больше, чем у пользователей smart, но не забываем про общий обьем выручки максимальная доля принадлежит тарифу smart - все дело в количестве пользователей
#
# **Выручка тарифов smart и ultra различаются**
# **Средняя выручка по Москве не отличается от общей совокупности других городов**

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)
