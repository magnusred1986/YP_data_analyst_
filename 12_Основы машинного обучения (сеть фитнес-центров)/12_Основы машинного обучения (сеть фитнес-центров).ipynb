# %% [markdown]
# <a name="contents"></a>
#  [Огравление](#stage_1)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-задач-проекта" data-toc-modified-id="Описание-задач-проекта-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Описание задач проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Откроем-файл-с-данными-и-изучим-общую-информацию" data-toc-modified-id="Откроем-файл-с-данными-и-изучим-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Откроем файл с данными и изучим общую информацию</a></span></li><li><span><a href="#Проведем-исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Проведем-исследовательский-анализ-данных-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Проведем исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-датасет:-есть-ли-в-нем-отсутствующие-признаки,-изучим-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe())" data-toc-modified-id="Посмотрим-на-датасет:-есть-ли-в-нем-отсутствующие-признаки,-изучим-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe())-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрим на датасет: есть ли в нем отсутствующие признаки, изучим средние значения и стандартные отклонения (пригодится метод describe())</a></span></li><li><span><a href="#Посмотрим-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby())" data-toc-modified-id="Посмотрим-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby())-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby())</a></span></li><li><span><a href="#Построим-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)" data-toc-modified-id="Построим-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)</a></span></li><li><span><a href="#Построим-матрицу-корреляций-и-отобразим-её" data-toc-modified-id="Построим-матрицу-корреляций-и-отобразим-её-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Построим матрицу корреляций и отобразим её</a></span></li></ul></li><li><span><a href="#Построим-модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Построим-модель-прогнозирования-оттока-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построим модель прогнозирования оттока клиентов</a></span></li><li><span><a href="#Сделаем-кластеризацию-клиентов" data-toc-modified-id="Сделаем-кластеризацию-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Сделаем кластеризацию клиентов</a></span></li><li><span><a href="#Сформулируем-выводы-и-сделаем-базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Сформулируем-выводы-и-сделаем-базовые-рекомендации-по-работе-с-клиентами-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сформулируем выводы и сделаем базовые рекомендации по работе с клиентами</a></span></li></ul></div>

# %% [markdown]
# ### Описание задач проекта
#
# **Шаг 1. Загрузите данные**
#
# Путь к файлу: `/datasets/gym_churn.csv.`
#
# **Шаг 2. Проведите исследовательский анализ данных (EDA)**
#
# * Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод `describe()`);
# * Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом `groupby()`);
# * Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# * Постройте матрицу корреляций и отобразите её.
#
# **Шаг 3. Постройте модель прогнозирования оттока клиентов**
#
# Постройте модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
# * Разбейте данные на обучающую и валидационную выборку функцией `train_test_split()`.
# * Обучите модель на `train`-выборке двумя способами:
#  * логистической регрессией,
#  * случайным лесом.
# * Оцените метрики `accuracy`, `precision` и `recall` для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
#
# Не забудьте указать параметр `random_state` при разделении выборки и задании алгоритма.
#
# **Шаг 4. Сделайте кластеризацию клиентов**
#
# Отложите в сторону столбец с оттоком и проведите кластеризацию объектов (клиентов):
# * Стандартизируйте данные.
# * Постройте матрицу расстояний функцией `linkage()` на стандартизованной матрице признаков и нарисуйте дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.
# * Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять `n=5`, чтобы ваши результаты можно было сравнивать с результатами остальных студентов. Однако, конечно, в жизни никто не скажет вам правильный ответ, и решение остаётся за вами (на основании изучения графика из предыдущего пункта).
# * Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?
# * Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?
# * Для каждого полученного кластера посчитайте долю оттока (методом `groupby()`). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?
#
# **Шаг 5. Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами**
#
# Сформулируйте основные выводы и предложите рекомендации для стратегии взаимодействия с клиентами и их удержания.
#
# Не описывайте стратегию детально: достаточно 3-4 важных принципов и примеров их реализации в виде определённых маркетинговых действий.

# %% [markdown]
# ### Описание данных
# * «Культурист-датасаентист» предоставил сведения в csv-файлах. Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц. Набор данных включает следующие поля:
# * **Данные клиента за предыдущий до проверки факта оттока месяц:**
#  * `gender` — пол;
#  * `Near_Location` — проживание или работа в районе, где находится фитнес-центр;
#  * `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
# Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#  * `Phone` — наличие контактного телефона;
#  * `Age` — возраст;
#  * `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах).
# * **Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:**
#  * `Contract_period` — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
#  * `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах);
#  * `Group_visits` — факт посещения групповых занятий;
#  * `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента;
#  * `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц;
#  * `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
#  * `Churn` — факт оттока в текущем месяце.

# %% [markdown]
# ## Откроем файл с данными и изучим общую информацию

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Импортируем библиотеки и датасет

# %%
import pandas as pd
import seaborn as sns
import itertools

import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore') # игнорируем предупреждения

pd.options.display.max_colwidth = 100 # увеличить максимальную ширину столбца
pd.set_option('display.max_columns', None) # макс кол-во отображ столбц

# %% [markdown]
# Прочитаем df

# %%
df = pd.read_csv('/datasets/gym_churn.csv')

# %% [markdown]
# Взглянем на данные

# %%
list_df = [df]
for i in list_df:
    display(i.head())
    display(i.info())
    display(i.isnull().sum())
    display(i.duplicated().sum())
    display(df.describe())
#    display(i.columns.tolist())
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %% [markdown]
# Нужно исправить регистр столбцов

# %%
#напишем функцию перевода столбцов к нижнему регистру и переведем в "питонячий формат))"  "_" 
# а следом цикл, который применит функцию

list_df = [df] # список с df для изменений

def replace_columns_names(df):
    list_of_columns = []
    for column in df.columns:
        column = column.lower()
        column = column.replace(' ', '_')
        list_of_columns.append(column)
    df.columns = list_of_columns
    return df

# применяем функцию к нашим df
for i in list_df:               # пробегаем по списку с df и подаем в обработку
    replace_columns_names(i)    # применение функции
    display(list(i.columns))    # вывод результата для визуальной оценки изменений
# Out:
# ['gender',
#  'near_location',
#  'partner',
#  'promo_friends',
#  'phone',
#  'contract_period',
#  'group_visits',
#  'age',
#  'avg_additional_charges_total',
#  'month_to_end_contract',
#  'lifetime',
#  'avg_class_frequency_total',
#  'avg_class_frequency_current_month',
#  'churn']

# %% [markdown]
# Взглянем на df

# %%
df.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %% [markdown]
# ## Проведем исследовательский анализ данных (EDA)

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# ### Посмотрим на датасет: есть ли в нем отсутствующие признаки, изучим средние значения и стандартные отклонения (пригодится метод describe())

# %%
df.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %%
# транспонируем
df.describe().transpose()
# Out:
#                                     count        mean        std        min  \
# gender                             4000.0    0.510250   0.499957   0.000000
# near_location                      4000.0    0.845250   0.361711   0.000000
# partner                            4000.0    0.486750   0.499887   0.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000
# phone                              4000.0    0.903500   0.295313   0.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000
# group_visits                       4000.0    0.412250   0.492301   0.000000
# age                                4000.0   29.184250   3.258367  18.000000
# avg_additional_charges_total       4000.0  146.943728  96.355602   0.148205
# month_to_end_contract              4000.0    4.322750   4.191297   1.000000
# lifetime                           4000.0    3.724750   3.749267   0.000000
# ...

# %% [markdown]
# `churn — факт оттока в текущем месяце` - в среднем отток составляет 27%
# `Phone` — свой телефон оставили 90% клиентов
# `gender` — пол- (женщин и мужчин) клиентов примерно поровну
# `partner` — сотрудник компании-партнёра клуба - 49% клиентов посещают клуб по корпоративным картам
# `promo_friends` - 30% клиентов пришли по промо коду
# `age`  — возраст- средний возраст 29 лет
# `lifetime` -  средний период посещения фитнес-йентра около 4 месяцев
# `group_visits`  —  групповые занятия посещают 41% клиентов
# `avg_additional_charges_total` - средние затраты клиентов на доп услуги 147 единиц
#
# У переменных разные по величине стандартные отклонения, но стандартизировать их мы не будем (не обязательно)

# %% [markdown]
# ### Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby())

# %%
df.groupby('churn', as_index=False).agg('mean').T.style # фиксим название столбца 'churn'
# Out:
# <style  type="text/css" >
# </style><table id="T_c3e95_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3e95_level0_row0" class="row_heading level0 row0" >churn</th>
#                         <td id="T_c3e95_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_c3e95_row0_col1" class="data row0 col1" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3e95_level0_row1" class="row_heading level0 row1" >gender</th>
#                         <td id="T_c3e95_row1_col0" class="data row1 col0" >0.510037</td>
#                         <td id="T_c3e95_row1_col1" class="data row1 col1" >0.510839</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ### Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)

# %% [markdown]
# Памятка: churn = 1 (отток)

# %%
df.columns
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
#        'avg_class_frequency_total', 'avg_class_frequency_current_month',
#        'churn'],
#       dtype='object')

# %%
# список - переводчик дабы понятнее все было, будем подтягивать с него пояснения
trans = {'gender':'пол', 'near_location': 'проживание или работа в районе, где находится фитнес-центр',
        'partner': ' сотрудник компании-партнёра клуба', 'promo_friends':'факт первоначальной записи в рамках акции «приведи друга»',
        'phone':'наличие контактного телефона', 'contract_period': 'длительность текущего действующего абонемента',
        'group_visits':'факт посещения групповых занятий', 'age':'возраст', 
         'avg_additional_charges_total':'суммарная выручка от других услуг фитнес-центра',
        'month_to_end_contract':'срок до окончания текущего действующего абонемента',
        'lifetime':' время с момента первого обращения в фитнес-центр',
        'avg_class_frequency_total':'средняя частота посещений в неделю за все время с начала действия абонемента',
        'avg_class_frequency_current_month':'средняя частота посещений в неделю за предыдущий месяц',
        'churn':'факт оттока в текущем месяце'} # условия для range Поиск по ключу

# %%
with plt.style.context('bmh'): # передали графику стиль
    for i in df.columns:                                                 # пробегаем по списку столбцов
        plt.figure(figsize=(10, 8))                                      # фиксим размер фигуры
        sns.distplot(df[i])                                              # рисуем гистограмму 
        plt.title(i + " - " + trans.get(i), fontsize = 15, fontweight="bold")# подаем переменную в название титульника 
        plt.show()                                                       # показываем
    # trans.get(i) ищет значение по ключу в списке

# %%
# напишем список исключений так как они не влияют на целевой признак 
not_print = ['avg_class_frequency_current_month', 'avg_class_frequency_total', 
             'avg_additional_charges_total']
for i in df.columns:
    if i not in not_print:
        with plt.style.context('bmh'): # передали графику стиль
            plt.figure(figsize=(10, 8))
            sns.countplot(x = df[i], hue='churn', data=df)
            plt.title(i + " - " + trans.get(i), fontsize = 15, fontweight="bold")
            plt.show()

# %% [markdown]
# `сходства/различия между классами:`
#
# `gender` - различий практически нет
# `near_location` - если фитнес-центр находится не в районе проживания, пропорция оттока больше
# `partner` - по сотрудникам компаниий отток меньше
# `promo_friends` - отток по партнерке меньше
# `phone` - наличисе контактного телефона никак не отражается на оттоке, пропорции приблизительно одинаковы
# `contract_period` - очень большой отток у тех, кто купил аббонемент на 1 месяц, чем дольше срок аббонемента, тем меньше вероятность оттока
# `group_visits` - при посещении центра группами, отток меньше, нежели при посещении в одичночку, компанией веселее и видимо данный факт носит соревновательный характер внутри группы персоналий
# `age` - 25-29 лет, основной возраст персоналий попадающих в отток
# `lifetime` - в основном уходят в первые 2 дня
# `month_to_end_contract` - здесь как и в случае с `contract_period`, большой отток у тех, кого аббонемент на 1 месяц (да и эти показатели с высокой корреляцией друг к другу)

# %% [markdown]
# ### Построим матрицу корреляций и отобразим её

# %%
cor = df.corr()
plt.figure(figsize=(14, 10))
sns.heatmap(cor, annot = True, fmt = '0.2f', square = True)
plt.title('Матрица корреляции', fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# исключим мультиколлинеарные признаки (достаточно по одному в паре):
# contract_period - month_to_end_contract
# vg_class_frequency_current_month - avg_class_frequency_total

# %%
cor = df.drop(['contract_period','avg_class_frequency_total'], axis = 1).corr()
plt.figure(figsize=(14, 10))
sns.heatmap(cor, annot = True, fmt = '0.2f', square = True)
plt.title('Матрица корреляции без мультиколлинеарности', fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# Целевая переменная `charn` бинарного типа (0 - клиент есть, 1 - отток клиента)
#
# Видим мультиколлинеарные признаки:
#  * contract_period - month_to_end_contract
#  * vg_class_frequency_current_month - avg_class_frequency_total
#
# Признаки с нулевой корреляцией по отношению к целевой переменной `charn`
#
#  * phone
#  * gender

# %% [markdown]
# ## Построим модель прогнозирования оттока клиентов

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Постройте модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце
#
# Разбейте данные на обучающую и валидационную выборку функцией `train_test_split()`.
#
# Обучите модель на train-выборке двумя способами:
# * логистической регрессией,
# * случайным лесом.
#
# Оцените метрики `accuracy, precision` и `recall` для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
#
# Не забудьте указать параметр `random_state` при разделении выборки и задании алгоритма.

# %%
# тема - Ансамбли деревьев: случайный лес и градиентный бустинг
# делим данные на признаки (матрица X) и целевую переменную (y)
X = df.drop('churn', axis = 1)
y = df['churn']

# %%
# определим функцию, которая будет выводить наши метрики
def print_all_metrics(y_true, y_pred, y_proba, title='Метрики классификации'):
    print(title)
    print('\tAccuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.2f}'.format(recall_score(y_true, y_pred)))
    #print('\tF1: {:.2f}'.format(f1_score(y_true, y_pred)))
    #print('\tROC_AUC: {:.2f}'.format(roc_auc_score(y_true, y_proba)))

# разделяем модель на обучающую и валидационную выборку 80/20 test_size=0.2 фиксим параметр случанойти random_state=0
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# создадим объект класса StandardScaler и применим его к обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# зададим алгоритм для модели логистической регрессии
lr_model = LogisticRegression(random_state = 0)
# обучим модель
lr_model.fit(X_train_st, y_train)
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
lr_predictions = lr_model.predict(X_test_st)
lr_probabilities = lr_model.predict_proba(X_test_st)[:, 1]
# выведем все метрики
print_all_metrics(
    y_test,
    lr_predictions,
    lr_probabilities,
    title='Метрики для модели логистической регрессии:',
)

# зададим алгоритм для новой модели на основе алгоритма случайного леса
cf_model = RandomForestClassifier(n_estimators = 100, random_state=0) # Ваш код здесь
# обучим модель случайного леса
cf_model.fit(X_train_st, y_train)
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
rf_predictions = cf_model.predict(X_test_st)# Ваш код здесь
rf_probabilities = cf_model.predict_proba(X_test_st)[:, 1]# Ваш код здесь
# выведем все метрики
print_all_metrics(
    y_test,
    rf_predictions,
    rf_probabilities,
    title='Метрики для модели случайного леса:'
)
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.92
# 	Precision: 0.85
# 	Recall: 0.83
# Метрики для модели случайного леса:
# 	Accuracy: 0.92
# 	Precision: 0.84
# 	Recall: 0.81

# %% [markdown]
# Попробуем поэспериментировать с количеством деревьев

# %%
# определим функцию, которая будет выводить наши метрики
def print_all_metrics(y_true, y_pred, y_proba, title='Метрики классификации'):
    print(title)
    print('\tAccuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.2f}'.format(recall_score(y_true, y_pred)))
    #print('\tF1: {:.2f}'.format(f1_score(y_true, y_pred)))
    #print('\tROC_AUC: {:.2f}'.format(roc_auc_score(y_true, y_proba)))

# разделяем модель на обучающую и валидационную выборку 80/20 test_size=0.2 фиксим параметр случанойти random_state=0
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# создадим объект класса StandardScaler и применим его к обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# зададим алгоритм для модели логистической регрессии
lr_model = LogisticRegression(random_state = 0)
# обучим модель
lr_model.fit(X_train_st, y_train)
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
lr_predictions = lr_model.predict(X_test_st)
lr_probabilities = lr_model.predict_proba(X_test_st)[:, 1]
# выведем все метрики
print_all_metrics(
    y_test,
    lr_predictions,
    lr_probabilities,
    title='Метрики для модели логистической регрессии:',
)

# список с кол-вом деревьев
estimators_amount = [50,100,500]
for i in estimators_amount:
    # зададим алгоритм для новой модели на основе алгоритма случайного леса
    cf_model = RandomForestClassifier(n_estimators = i, random_state=0) # Ваш код здесь
    # обучим модель случайного леса
    cf_model.fit(X_train_st, y_train)
    # воспользуемся уже обученной моделью, чтобы сделать прогнозы
    rf_predictions = cf_model.predict(X_test_st)# Ваш код здесь
    rf_probabilities = cf_model.predict_proba(X_test_st)[:, 1]# Ваш код здесь
    # выведем все метрики
    print_all_metrics(
        y_test,
        rf_predictions,
        rf_probabilities,
        title='Метрики для модели случайного леса:'+str(i)
    )
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.92
# 	Precision: 0.85
# 	Recall: 0.83
# Метрики для модели случайного леса:50
# 	Accuracy: 0.92
# 	Precision: 0.85
# 	Recall: 0.83
# Метрики для модели случайного леса:100
# 	Accuracy: 0.92
# 	Precision: 0.84
# 	Recall: 0.81
# Метрики для модели случайного леса:500
# 	Accuracy: 0.92
# 	Precision: 0.84
# 	Recall: 0.82

# %% [markdown]
# Метрики логистической регрессии более привлекательны

# %% [markdown]
# ## Сделаем кластеризацию клиентов

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
df_sс = df.drop(['churn'], axis=1)
df_columns_list = df_sс.columns
df_sс = StandardScaler().fit_transform(df_sс) # стандартизируем данные 
df_sс = pd.DataFrame(df_sс, columns = df_columns_list).astype('float64')

# %%
# строим матрицу расстояний функцией linkage() на стандартизованной матрице признаков
linked = linkage(df_sс, method = 'ward')

# %%
# рисуем дендраграмму
plt.figure(figsize=(16, 9))  
dendrogram(linked, orientation = 'top')
plt.title('Иерархическая кластеризация пользователей', fontsize = 15, fontweight="bold")
plt.show()

# %%
# столбцов в матрице
linked.shape
# Out:
# (3999, 4)

# %% [markdown]
# Предположенное оптимально число кластеров 4 - четыре цвета на графике и столбцов в матрице

# %%
# задаём модель k_means с числом кластеров 3 и фиксируем значение random_state
km = KMeans(n_clusters=5, random_state=0)
# прогнозируем кластеры для наблюдений (алгоритм присваивает им номера от 0 до 2)
labels = km.fit_predict(df_sс)

# сохраняем метки кластера в поле нашего датасета
df['cluster'] = labels

# выводим статистику по средним значениям наших признаков по кластеру
df.groupby(['cluster']).mean()
# Out:
#            gender  near_location   partner  promo_friends     phone  \
# cluster
# 0        0.502970       0.959406  0.783168       0.574257  1.000000
# 1        0.522078       0.862338  0.470130       0.306494  0.000000
# 2        0.495050       0.000000  0.463366       0.079208  1.000000
# 3        0.485737       1.000000  0.350238       0.240095  1.000000
# 4        0.559666       0.976134  0.356802       0.230310  0.998807
#
#          contract_period  group_visits        age  \
# cluster
# 0              10.889109      0.542574  29.982178
# 1               4.787013      0.425974  29.301299
# 2               2.352475      0.215842  28.477228
# 3               1.948494      0.341521  28.167987
# 4               2.669451      0.473747  30.125298
#
#          avg_additional_charges_total  month_to_end_contract  lifetime  \
# cluster
# 0                          160.761016               9.954455  4.736634
# 1                          143.957664               4.475325  3.924675
# ...

# %%
# распределение признаков по кластерам
countss = df.cluster.value_counts().reset_index()
countss = countss.sort_values(
        by='cluster', ascending = False)
countss
# Out:
#    index  cluster
# 0      3     1262
# 1      0     1010
# 2      4      838
# 3      2      505
# 4      1      385

# %%
with plt.style.context('bmh'): # стиль 
    plt.figure(figsize=(18, 8)) # размер фигуры
    sns.barplot(x='index', y='cluster', data=countss,
                palette="Set2_r") # стиль свеч palette="Set2"
    plt.xlabel('Кластеры', fontsize = 12, fontweight = 'bold')
    plt.ylabel('Количество', fontsize = 12, fontweight = 'bold')
    plt.title('Распределение признаков по кластерам',
              fontsize = 15, fontweight = 'bold') # заголовок 
    plt.xticks(rotation=0)

# %% [markdown]
# Больше всего признаков в кластерах 3 и 0

# %%
# взглянем на средние значения по клачтерам/признакам
df.groupby('cluster').mean().T.round(2)
# Out:
# cluster                                 0       1       2       3       4
# gender                               0.50    0.52    0.50    0.49    0.56
# near_location                        0.96    0.86    0.00    1.00    0.98
# partner                              0.78    0.47    0.46    0.35    0.36
# promo_friends                        0.57    0.31    0.08    0.24    0.23
# phone                                1.00    0.00    1.00    1.00    1.00
# contract_period                     10.89    4.79    2.35    1.95    2.67
# group_visits                         0.54    0.43    0.22    0.34    0.47
# age                                 29.98   29.30   28.48   28.17   30.13
# avg_additional_charges_total       160.76  143.96  135.46  131.62  161.66
# month_to_end_contract                9.95    4.48    2.20    1.86    2.46
# lifetime                             4.74    3.92    2.81    2.44    4.90
# avg_class_frequency_total            1.98    1.85    1.66    1.25    2.85
# ...

# %%
# Для каждого полученного кластера посчитаем долю оттока
df.query('churn == 1').groupby('cluster').size() / len(df)*100
# подробное описание будет ниже в конце раздела 4
# Out:
# cluster
# 0     0.700
# 1     2.575
# 2     5.600
# 3    16.225
# 4     1.425
# dtype: float64

# %% [markdown]
# Максимальная доля оттока по 3 кластеру

# %% [markdown]
# Сформируем df для построения графика

# %%
df1 = df.groupby(['cluster','churn']).count().reset_index()

# %% [markdown]
# Посмотрим на распределение в кластерах на графике

# %%
fig, ax = plt.subplots(figsize=(14, 10))

# Our x-axis. We basically just want a list
# of numbers from zero with a value for each
# of our jobs.
x = np.arange(len(df1.cluster.unique()))

bar_width = 0.4

b1 = ax.bar(x, df1.loc[df1['churn'] == 0, 'near_location'], label = 'churn 0 - не попали в отток', width = bar_width)
b2 = ax.bar(x + bar_width, df1.loc[df1['churn'] == 1, 'near_location'], label = 'churn 1 - отток', width = bar_width)

ax.legend()

plt.title('Распределение оттока в кластерах',
              fontsize = 15, fontweight = 'bold')

ax.set_xlabel('Кластеры', labelpad = 15, fontsize = 12, fontweight="bold")

for bar in ax.patches:
  # The text annotation for each bar should be its height.
  bar_value = bar.get_height()
  # Format the text with commas to separate thousands. You can do
  # any type of formatting here though.
  text = f'{bar_value:,}'
  # This will give the middle of each bar on the x-axis.
  text_x = bar.get_x() + bar.get_width() / 2
  # get_y() is where the bar starts so we add the height to it.
  text_y = bar.get_y() + bar_value
  # If we want the text to be the same color as the bar, we can
  # get the color like so:
  bar_color = bar.get_facecolor()
  # If you want a consistent color, you can just set it as a constant, e.g. #222222
  ax.text(text_x, text_y, text, ha='center', va='bottom', color=bar_color,
          size=12)

# %%
claster = x = np.arange(len(df.cluster.unique()))
# доля оттока внутри каждого кластера колво по признаку кластера и оттока / общее кол-во в кластере
for i in claster:
    print('Доля оттока внутри кластера ' + str(i)," = ",df.query('cluster == @i and churn == 1').count()[1]
          , 'единиц, что составляет',
         ': {:.2%}'.format(df.query('cluster == @i and churn == 1').count()[1]/df.query('cluster == @i').count()[1]), 
          'от общего количества', df.query('cluster == @i').count()[1])
print('---------------------------------------------------------------------------------------------')
# доля оттока от общего колич с признаком оттока и кластера / на общее кол-во строк 4000
for i in claster:
    print('Доля оттока в общей массе по кластеру ' + str(i),': {:.2%}'.format(df.query('cluster == @i and churn == 1')
                                                                              .count()[1]/len(df)))
print('---------------------------------------------------------------------------------------------')
# Out:
# Доля оттока внутри кластера 0  =  28 единиц, что составляет : 2.77% от общего количества 1010
# Доля оттока внутри кластера 1  =  103 единиц, что составляет : 26.75% от общего количества 385
# Доля оттока внутри кластера 2  =  224 единиц, что составляет : 44.36% от общего количества 505
# Доля оттока внутри кластера 3  =  649 единиц, что составляет : 51.43% от общего количества 1262
# Доля оттока внутри кластера 4  =  57 единиц, что составляет : 6.80% от общего количества 838
# ---------------------------------------------------------------------------------------------
# Доля оттока в общей массе по кластеру 0 : 0.70%
# Доля оттока в общей массе по кластеру 1 : 2.57%
# Доля оттока в общей массе по кластеру 2 : 5.60%
# Доля оттока в общей массе по кластеру 3 : 16.23%
# Доля оттока в общей массе по кластеру 4 : 1.43%
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# Оптимальное количество кластеров 4, согласно количеству цветов, но по условию выводим 5.
# Оттоки внутри кластеров:
# * Наибольшее количество признаков по кластерам кластерам, у кластеров 3 и 0
# * Слабые оттоки по кластерам 0 и 4
# * Сильный отток по 3-2-1 кластеру по убыванию

# %% [markdown]
# Разделим переменные на дискретные и непрерывные

# %%
discrete = ['gender', 'near_location', 'partner', 'promo_friends', 'phone', 'group_visits','cluster']
continuous = ['contract_period', 'age', 'avg_additional_charges_total', 'month_to_end_contract', 'lifetime', 
            'avg_class_frequency_total', 'avg_class_frequency_current_month']

# %% [markdown]
# Распределение по кластерам:

# %%
# напишем список исключений так как они не влияют на целевой признак 
not_print = ['avg_class_frequency_current_month', 'avg_class_frequency_total', 
             'avg_additional_charges_total']
for i in df.columns:
    if i not in not_print:
        if i in discrete:
            with plt.style.context('bmh'): # передали графику стиль
                try:

                    plt.figure(figsize=(10, 8))
                    sns.countplot(x = df[i], hue='cluster', data=df)
                    plt.title(i + " - " + str(trans.get(i)), fontsize = 15, fontweight="bold")
                    plt.show()
                except:
                    print('что-то пошло не так', i)

# %%
for i in df.columns:
    if i not in discrete:
        with plt.style.context('bmh'): # передали графику стиль    
            plt.figure(figsize=(12, 4))  # размер фигуры
            sns.boxplot(data=df, y=i, x='cluster') # построение графика
            plt.title(i + " - " + str(trans.get(i)), fontsize = 15, fontweight="bold") # размеры и оглавление

# %%
for i in df.columns:
    with plt.style.context('bmh'): # передали графику стиль  
        plt.figure(figsize=(12, 4))  
        sns.barplot(data=df, y=i, x='cluster')
        plt.title(i + " - " + str(trans.get(i)), fontsize = 15, fontweight="bold") # размеры и оглавление

# %% [markdown]
# **Описание портрета пользователей по кластерам:**

# %%
# цикл описание портрета пользователя по кластерам

# "\033[1m"  - старт жирного курсива
# "\033[0;0m" - - стоп жирного курсива

for j in range(df['cluster'].max()+1): # смотрим кол-во кластеров в df по нему будем rang - ить
    print("\033[1m" + 'Описание пользователя, кластера'+"\033[0;0m", j)  # выводим кластер который в переменной, стартует с 0
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")#разделитель
    xqwerty = df.query('cluster == @j').describe().transpose().reset_index() # по query подаем кластер для формирования df
    xqwerty
    for i in range(xqwerty.shape[0]): # пол-во строк в сформированном df после query
        print("\033[1m" + xqwerty.iloc[i]['index'] +"\033[0;0m"," - ",trans.get(xqwerty.iloc[i]['index']),
              " - ", xqwerty.iloc[i]['mean'].round(2)) # на print подаем значения df по iloc
# Out:
# Описание пользователя, кластера 0
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gender  -  пол  -  0.5
# near_location  -  проживание или работа в районе, где находится фитнес-центр  -  0.96
# partner  -   сотрудник компании-партнёра клуба  -  0.78
# promo_friends  -  факт первоначальной записи в рамках акции «приведи друга»  -  0.57
# phone  -  наличие контактного телефона  -  1.0
# contract_period  -  длительность текущего действующего абонемента  -  10.89
# group_visits  -  факт посещения групповых занятий  -  0.54
# age  -  возраст  -  29.98
# avg_additional_charges_total  -  суммарная выручка от других услуг фитнес-центра  -  160.76
# month_to_end_contract  -  срок до окончания текущего действующего абонемента  -  9.95
# lifetime  -   время с момента первого обращения в фитнес-центр  -  4.74
# avg_class_frequency_total  -  средняя частота посещений в неделю за все время с начала действия абонемента  -  1.98
# ...

# %%
# взглянем на средние значения по клачтерам/признакам
# так удобнее, без описательной части
df.groupby('cluster').mean().T.round(2)
# Out:
# cluster                                 0       1       2       3       4
# gender                               0.50    0.52    0.50    0.49    0.56
# near_location                        0.96    0.86    0.00    1.00    0.98
# partner                              0.78    0.47    0.46    0.35    0.36
# promo_friends                        0.57    0.31    0.08    0.24    0.23
# phone                                1.00    0.00    1.00    1.00    1.00
# contract_period                     10.89    4.79    2.35    1.95    2.67
# group_visits                         0.54    0.43    0.22    0.34    0.47
# age                                 29.98   29.30   28.48   28.17   30.13
# avg_additional_charges_total       160.76  143.96  135.46  131.62  161.66
# month_to_end_contract                9.95    4.48    2.20    1.86    2.46
# lifetime                             4.74    3.92    2.81    2.44    4.90
# avg_class_frequency_total            1.98    1.85    1.66    1.25    2.85
# ...

# %% [markdown]
# ## Сформулируем выводы и сделаем базовые рекомендации по работе с клиентами

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Согласно исследованию:
# `churn` — факт оттока в текущем месяце - в среднем отток составляет 27%
# `phone` — свой телефон оставили 90% клиентов
# `gender` — пол- (женщин и мужчин) клиентов примерно поровну
# `partner` — сотрудник компании-партнёра клуба - 49% клиентов посещают клуб по корпоративным картам promo_friends - 30% клиентов пришли по промо коду
# `age` — возраст- средний возраст 29 лет
# `lifetime` - средний период посещения фитнес-йентра около 4 месяцев
# `group_visits` — групповые занятия посещают 41% клиентов
# `avg_additional_charges_total` - средние затраты клиентов на доп услуги 147 единиц
# У переменных разные по величине стандартные отклонения, мы их не стандартизировали
#
# Есть мультиколлинеарные признаки:
# •	`contract_period - month_to_end_contract`
# •	`vg_class_frequency_current_month - avg_class_frequency_total`
#
#
# * Разлиия по кластерам:
# 0 кластер живут дольше всех
# 1 кластер в основном ходят без партнера, но посещают групповые занятия, мало тратят на доп. услуги
# 2 кластер живут близко, ходят с партнером, пришли по промоакции, достаточно много тратят, доля оттока низкая
# 3 кластер живут близко но при этом самые "отточные", совсем не посещают групповые занятия, меньше всех тратят
# 4 кластер самый лояльный, пришли не по промоакции, больше всех тратят
#
#
# •	Наибольшее количество признаков по кластерам кластерам, у кластеров 3 и 0
# •	Слабые оттоки по кластерам 0 и 4
# •	Сильный отток по 3-2-1 кластеру по убыванию
#
# Для закупки трафика и привличения пользователей использовать удержание аудитории из кластеров с минимальным оттоком.
# Поддерживать и мотивировать кластеры с минимальным оттоком.
# Глубже сегментировать оттекающих, к каждому сегменту тестировать индивидуальные предложения. Выяснить причины оттока пользователей, быть более клиентоориенттированными в сегментах с повышеным оттоком.
# Упреждать действие оттока.
#
# Мартетинговые действия (рекомендации):
# * В партнерку добавить накопительную скидку. То есть, допустим за 1 друга минус 2% от стоимости аббонемента на следующий год или месяц, в период пролонгации. Но с условием, что приведенный друг посетит центр не менее 5 раз.
# * Дополнительный пакет или услуга, для тех, кто покупает аббонемент на длительный срок
# * Расширить предложения по доп услугам. Возможно сдлеать опрос среди клиентов, о пожеланиях или же попросить заполнить анкетку, а для стимуляции, использовать вознаграждение - протеиновый батончик или какую нибудь резинку на запястье с красивым лозунгом на выбор ))) Что нибудь бесплатное. это всегда приятно )
