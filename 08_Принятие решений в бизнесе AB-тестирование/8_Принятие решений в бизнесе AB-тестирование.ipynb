# %% [markdown]
# <a name="contents"></a>
#  [Огравление](#stage_1)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span><strong>Описание данных</strong></a></span></li><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span><strong>Описание проекта</strong></a></span></li><li><span><a href="#Импортируем-библиотеки-и-датасеты" data-toc-modified-id="Импортируем-библиотеки-и-датасеты-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Импортируем библиотеки и датасеты</a></span></li><li><span><a href="#Приведем-df-мы-в-&quot;змеиный_регистр&quot;" data-toc-modified-id="Приведем-df-мы-в-&quot;змеиный_регистр&quot;-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Приведем df-мы в "змеиный_регистр"</a></span></li><li><span><a href="#Проверим-на-наличие-дубликатов" data-toc-modified-id="Проверим-на-наличие-дубликатов-0.5"><span class="toc-item-num">0.5&nbsp;&nbsp;</span>Проверим на наличие дубликатов</a></span></li></ul></li><li><span><a href="#Часть-1.-Приоритизация-гипотез." data-toc-modified-id="Часть-1.-Приоритизация-гипотез.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Часть 1. Приоритизация гипотез.</strong></a></span><ul class="toc-item"><li><span><a href="#Применим-фреймворк-ICE-для-приоритизации-гипотез.---Отсортируем-их-по-убыванию-приоритета." data-toc-modified-id="Применим-фреймворк-ICE-для-приоритизации-гипотез.---Отсортируем-их-по-убыванию-приоритета.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Применим фреймворк <code>ICE</code> для приоритизации гипотез.   Отсортируем их по убыванию приоритета.</a></span></li><li><span><a href="#Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета." data-toc-modified-id="Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Применим фреймворк <code>RICE</code> для приоритизации гипотез. Отсортируем их по убыванию приоритета.</a></span></li><li><span><a href="#Изменение-приоритизации-гипотез-при-применении-RICE-вместо-ICE.-Объясним,-почему-так-произошло." data-toc-modified-id="Изменение-приоритизации-гипотез-при-применении-RICE-вместо-ICE.-Объясним,-почему-так-произошло.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Изменение приоритизации гипотез при применении <code>RICE</code> вместо <code>ICE</code>. Объясним, почему так произошло.</a></span></li></ul></li><li><span><a href="#Часть-2.-Анализ-A/B-теста" data-toc-modified-id="Часть-2.-Анализ-A/B-теста-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>Часть 2. Анализ A/B-теста</strong></a></span><ul class="toc-item"><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам.-Сделаем-выводы-и-предположения.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Построим <code>график кумулятивной выручки</code> по группам. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-кумулятивного-среднего-чека-по-группам.-Сделайте-выводы-и-предположения" data-toc-modified-id="Постройте-график-кумулятивного-среднего-чека-по-группам.-Сделайте-выводы-и-предположения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Постройте <code>график кумулятивного среднего чека</code> по группам. Сделайте выводы и предположения</a></span></li><li><span><a href="#Постройте-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделайте-выводы-и-предположения.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Постройте <code>график относительного изменения кумулятивного среднего чека</code> группы B к группе A. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-кумулятивной-конверсии-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивной-конверсии-по-группам.-Сделайте-выводы-и-предположения.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Постройте <code>график кумулятивной конверсии по группам</code>. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A.-Сделайте-выводы-и-предположения.-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Постройте <code>график относительного изменения кумулятивной конверсии</code> группы B к группе A. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-точечный-график-количества-заказов-по-пользователям.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-точечный-график-количества-заказов-по-пользователям.-Сделайте-выводы-и-предположения.-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Постройте точечный <code>график количества заказов по пользователям</code>. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей." data-toc-modified-id="Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей.-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Посчитайте <code>95-й и 99-й перцентили количества заказов на пользователя</code>. Выберите границу для определения аномальных пользователей.</a></span></li><li><span><a href="#Постройте-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения.-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Постройте <code>точечный график стоимостей заказов</code>. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-95-й-и-99-й-перцентили-стоимости-заказов.-Выберите-границу-для-определения-аномальных-заказов." data-toc-modified-id="Посчитайте-95-й-и-99-й-перцентили-стоимости-заказов.-Выберите-границу-для-определения-аномальных-заказов.-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Посчитайте <code>95-й и 99-й перцентили стоимости заказов</code>. Выберите границу для определения аномальных заказов.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения.-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Посчитайте <code>статистическую значимость различий в конверсии между группами по «сырым» данным</code>. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения.-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Посчитайте <code>статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным</code>. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения.-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Посчитайте <code>статистическую значимость различий в конверсии между группами по «очищенным» данным</code>. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения.-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Посчитайте <code>статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным</code>. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Примите-решение-по-результатам-теста-и-объясните-его." data-toc-modified-id="Примите-решение-по-результатам-теста-и-объясните-его.-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Примите решение по результатам теста и объясните его.</a></span><ul class="toc-item"><li><span><a href="#Сравнение-выручки-по-группам-без-аномалий" data-toc-modified-id="Сравнение-выручки-по-группам-без-аномалий-2.14.1"><span class="toc-item-num">2.14.1&nbsp;&nbsp;</span>Сравнение выручки по группам без аномалий</a></span></li><li><span><a href="#График-кумулятивной-выручки-по-дням-и-группам-без-аномалий" data-toc-modified-id="График-кумулятивной-выручки-по-дням-и-группам-без-аномалий-2.14.2"><span class="toc-item-num">2.14.2&nbsp;&nbsp;</span>График кумулятивной выручки по дням и группам без аномалий</a></span></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам-без-аномалий" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-без-аномалий-2.14.3"><span class="toc-item-num">2.14.3&nbsp;&nbsp;</span>График кумулятивного среднего чека по группам без аномалий</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ### **Описание данных**
#
# Данные для первой части
# Файл `/datasets/hypothesis.csv.`
# * `Hypothesis` — краткое описание гипотезы;
# * `Reach` — охват пользователей по 10-балльной шкале;
# * `Impact` — влияние на пользователей по 10-балльной шкале;
# * `Confidence` — уверенность в гипотезе по 10-балльной шкале;
# * `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# **Данные для второй части**
# Файл `/datasets/orders.csv.`
# * `transactionId` — идентификатор заказа;
# * `visitorId` — идентификатор пользователя, совершившего заказ;
# * `date` — дата, когда был совершён заказ;
# * `revenue` — выручка заказа;
# * `group` — группа A/B-теста, в которую попал заказ.
#
# Файл `/datasets/visitors.csv`.
# * `date` — дата;
# * `group` — группа A/B-теста;
# * `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# ### **Описание проекта**
#
# **Часть 1. Приоритизация гипотез.**
# В файле `/datasets/hypothesis.csv` 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами `Reach, Impact, Confidence, Effort.`
#
# **Задача**
# * Примените фреймворк `ICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# * Примените фреймворк `RICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# * Укажите, как изменилась приоритизация гипотез при применении `RICE` вместо `ICE`. Объясните, почему так произошло.
#
# **Часть 2. Анализ A/B-теста**
# Вы провели A/B-тест и получили результаты, которые описаны в файлах `/datasets/orders.csv` и `/datasets/visitors.csv.`
#
# **Задача**
# Проанализируйте A/B-тест:
# 1. Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# 2. Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# 3. Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# 4. Постройте график кумулятивной конверсии по группам. Сделайте выводы и предположения.
# 5. Постройте график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.
# 6. Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# 7. Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# 8. Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# 9. Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# 10. Посчитайте статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.
# 11. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# 12. Посчитайте статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.
# 13. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# 14. Примите решение по результатам теста и объясните его. Варианты решений: 1. Остановить тест, зафиксировать победу одной из групп. 2. Остановить тест, зафиксировать отсутствие различий между группами. 3. Продолжить тест.

# %% [markdown]
# ### Импортируем библиотеки и датасеты

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
import pandas as pd
import scipy.stats as stats
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_colwidth = 100 # увеличить максимальную ширину столбца

# %% [markdown]
# Прочитаем df-мы

# %%
df_hypothesis = pd.read_csv('/datasets/hypothesis.csv', sep=',')
df_orders = pd.read_csv('/datasets/orders.csv', sep=',')
df_visitors = pd.read_csv('/datasets/visitors.csv', sep=',')

# %%
list_df = [df_hypothesis, df_orders, df_visitors]
for i in list_df:
    display(i.head())
    display(i.info())
# Out:
#                                                                                             Hypothesis  \
# 0   Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                            Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средни...
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                     Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#    Reach  Impact  Confidence  Efforts
# 0      3      10           8        6
# 1      2       5           4       10
# 2      8       3           7        3
# 3      8       3           3        8
# 4      3       1           1        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
# ...

# %% [markdown]
# ### Приведем df-мы в "змеиный_регистр"

# %%
#напишем функцию перевода столбцов к нижнему регистру и переведем в "питонячий формат))"  "_" 
# а следом цикл, который применит функцию

list_df = [df_hypothesis, df_orders, df_visitors] # список с df для изменений

def replace_columns_names(df):
    list_of_columns = []
    for column in df.columns:
        column = column.lower()
        column = column.replace(' ', '_')
        list_of_columns.append(column)
    df.columns = list_of_columns
    return df

# применяем функцию к нашим df
for i in list_df:               # пробегаем по списку с df и подаем в обработку
    replace_columns_names(i)    # применение функции
    display(list(i.columns))    # вывод результата для визуальной оценки изменений
# Out:
# ['hypothesis', 'reach', 'impact', 'confidence', 'efforts']
# ['transactionid', 'visitorid', 'date', 'revenue', 'group']
# ['date', 'group', 'visitors']

# %% [markdown]
# ### Проверим на наличие дубликатов

# %%
for i in list_df:
    display(i.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
df_hypothesis
# Out:
#                                                                                             hypothesis  \
# 0   Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                            Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средни...
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                     Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5             Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конве...
# 7     Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# ...

# %% [markdown]
# В предобработке данных - были выявлены и устранены проблемы с регистром в названии столбцов

# %% [markdown]
# ## **Часть 1. Приоритизация гипотез.**

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# ### Применим фреймворк `ICE` для приоритизации гипотез.   Отсортируем их по убыванию приоритета.

# %%
df_hypothesis['ICE'] = (df_hypothesis['impact']*df_hypothesis['confidence'])/df_hypothesis['efforts']
df_hypothesis[['hypothesis','ICE']].sort_values('ICE', ascending=False)
# Out:
#                                                                                             hypothesis  \
# 8                                              Запустить акцию, дающую скидку на товар в день рождения
# 0   Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7     Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конве...
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средни...
# 1                            Запустить собственную службу доставки, что сократит срок доставки заказов
# 5             Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# ...

# %%
display('Наиболее приоритетная гипотеза: ', df_hypothesis[df_hypothesis['ICE'] == df_hypothesis['ICE'].max()])
# Out:
# 'Наиболее приоритетная гипотеза: '
#                                                 hypothesis  reach  impact  \
# 8  Запустить акцию, дающую скидку на товар в день рождения      1       9
#
#    confidence  efforts   ICE
# 8           9        5  16.2

# %% [markdown]
# ### Применим фреймворк `RICE` для приоритизации гипотез. Отсортируем их по убыванию приоритета.

# %%
# RICE = (Reach x Impact x Confidence)/Efforts

df_hypothesis['RICE'] = (df_hypothesis['reach']*df_hypothesis['impact']*df_hypothesis['confidence'])/df_hypothesis['efforts']

df_hypothesis[['hypothesis','RICE']].sort_values('RICE', ascending=False)
# Out:
#                                                                                             hypothesis  \
# 7     Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средни...
# 0   Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конве...
# 8                                              Запустить акцию, дающую скидку на товар в день рождения
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                            Запустить собственную службу доставки, что сократит срок доставки заказов
# 5             Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %%
display('Наиболее приоритетная гипотеза: ', df_hypothesis[df_hypothesis['RICE'] == df_hypothesis['RICE'].max()])
# Out:
# 'Наиболее приоритетная гипотеза: '
#                                                                                          hypothesis  \
# 7  Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
#
#    reach  impact  confidence  efforts   ICE   RICE
# 7     10       7           8        5  11.2  112.0

# %% [markdown]
# ### Изменение приоритизации гипотез при применении `RICE` вместо `ICE`. Объясним, почему так произошло.

# %% [markdown]
# **Наглядное отображение приоритезации гипотез**

# %%
plt.figure(figsize=(18,8))
plt.title('График значений метода ICE и RICE', size=15)
sns.scatterplot(x=df_hypothesis['ICE'], y=df_hypothesis['RICE'])
for line in range(0,df_hypothesis.shape[0]):
     plt.text(df_hypothesis.ICE[line]+0.2, 
              df_hypothesis.RICE[line], 
              df_hypothesis.index[line], 
              horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.show()

# %% [markdown]
# Данные изменились так как параметр `RICE` состоит из 4 компонентов и в числителе 3 из них учавствуют в произведении,
# дополнительно учавствует параметр `reach` — охват пользователей

# %% [markdown]
# На графике хорошо видно что по `ICE` более приоритетной является гипотеза `8 - Запустить акцию, дающую скидку на товар в день рождения`, тогда как по `RICE` приоритетнее оказалась `7 - Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок`. Параметр охвата пользователей `reach` является дополнительным в числителе, что увеличичивает общую сумму произведения, что в свою очередь отражается на изменении значений.

# %% [markdown]
# ## **Часть 2. Анализ A/B-теста**

# %% [markdown]
# ### Построим `график кумулятивной выручки` по группам. Сделаем выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Подготовка данных

# %%
df_orders['date'] = df_orders['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
df_visitors['date'] = df_visitors['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %%
display(df_orders.head())
display(df_visitors.head())
# Out:
#    transactionid   visitorid       date  revenue group
# 0     3667963787  3312258926 2019-08-15     1650     B
# 1     2804400009  3642806036 2019-08-15      730     B
# 2     2961555356  4069496402 2019-08-15      400     A
# 3     3797467345  1196621759 2019-08-15     9759     B
# 4     2282983706  2322279887 2019-08-15     2308     B
#         date group  visitors
# 0 2019-08-01     A       719
# 1 2019-08-02     A       619
# 2 2019-08-03     A       507
# 3 2019-08-04     A       717
# 4 2019-08-05     A       756

# %% [markdown]
# Создадим массив уникальных пар значений дат и групп теста методом drop_duplicates()

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = df_orders[['date','group']].drop_duplicates()
datesGroups.head()
# Out:
#          date group
# 0  2019-08-15     B
# 2  2019-08-15     A
# 45 2019-08-16     A
# 47 2019-08-16     B
# 55 2019-08-01     A

# %% [markdown]
# Соберём агрегированные кумулятивные по дням данные о заказах

# %%
ordersAggregated = datesGroups.apply(
    lambda x: df_orders[np.logical_and(df_orders['date'] <= x['date'], df_orders['group'] == x['group'])]
    .agg({'date' : 'max', 'group' : 'max', 'transactionid' : 'nunique', 'visitorid' : 'nunique', 'revenue' : 'sum'})
    , axis=1).sort_values(by=['date','group'])

# %% [markdown]
# Соберём агрегированные кумулятивные по дням данные о посетителях

# %%
visitorsAggregated = datesGroups.apply(
    lambda x: df_visitors[np.logical_and(df_visitors['date'] <= x['date'], df_visitors['group'] == x['group'])]
    .agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %% [markdown]
# Объединим кумулятивные данные

# %%
# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия

cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
print(cumulativeData.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      24      20   148579       719
# 1 2019-08-01     B      21      20   101217       713
# 2 2019-08-02     A      44      38   242401      1338
# 3 2019-08-02     B      45      43   266748      1294
# 4 2019-08-03     A      68      62   354874      1845

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]


plt.figure(figsize=(15,8)) # размер графика
# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

# градус подписей по оси Х
plt.xticks(rotation=45)

plt.legend()

plt.ylabel('Выручка',fontsize = 15, fontweight="bold")
plt.xlabel('Период',fontsize = 15, fontweight="bold")
plt.title('График кумулятивной выручки по дням и группам',fontsize = 15, fontweight="bold")
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Выручка группы В значительно возрасла на середине теста, это сигнализирует о всплеске числа заказов по группе В,
# да и в целом, показатель группы В выше

# %% [markdown]
# ### Постройте `график кумулятивного среднего чека` по группам. Сделайте выводы и предположения

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
plt.figure(figsize=(15,8)) # размер графика
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.legend()

# градус подписей по оси Х
plt.xticks(rotation=45)

plt.ylabel('Средний чек',fontsize = 15, fontweight="bold")
plt.xlabel('Период',fontsize = 15, fontweight="bold")
plt.title('График кумулятивного среднего чека по группам',fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# Средний чек группы В так же занимает лидирующую позицию, насмотря на слабый старт теста, как и по выручке, виден всплеск
# на середенине теста, что говорит о возможном попадании крупных заказов в середине теста в группу В

# %% [markdown]
# ### Постройте `график относительного изменения кумулятивного среднего чека` группы B к группе A. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.figure(figsize=(15,8)) # размер графика
# cтроим отношение средних чеков
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')

# градус подписей по оси Х
plt.xticks(rotation=45)

plt.ylabel('Отношение',fontsize = 15, fontweight="bold")
plt.xlabel('Период',fontsize = 15, fontweight="bold")
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A',fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# Видим резкие скачки в графике различия между сегментами, это говорит о крупных заказах или выбросах.
# В середине теста группа B значительно хуже себя показываетв отношении к группе А, видимо это связано с средним чеком,
# ведь в группе В кумулятивный средний чек гораздо меньше группы А именно в середине теста

# %% [markdown]
# ### Постройте `график кумулятивной конверсии по группам`. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
# считаем кумулятивную конверсию
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

plt.figure(figsize=(15,8)) # размер графика
# строим графики
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()

# задаем масштаб осей
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), 0, 0.05])


# градус подписей по оси Х
plt.xticks(rotation=45)

plt.ylabel('Отношение',fontsize = 15, fontweight="bold")
plt.xlabel('Период',fontsize = 15, fontweight="bold")
plt.title('График кумулятивной конверсии по группам',fontsize = 15, fontweight="bold")

plt.show()

# %% [markdown]
# Относительно симметричный график, колебания были вначале теста, конверсия группы В вырвалась вперед
# и зафиксировалась относительно группы А, тест которой проходил так же стабильно

# %% [markdown]
# ### Постройте `график относительного изменения кумулятивной конверсии` группы B к группе A. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])
plt.figure(figsize=(15,8)) # размер графика
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост конверсии группы B относительно группы A")
plt.legend()

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.15, color='grey', linestyle='--')
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), -0.15, 0.3])

# градус подписей по оси Х
plt.xticks(rotation=45)

plt.ylabel('Отношение',fontsize = 15, fontweight="bold")
plt.xlabel('Период',fontsize = 15, fontweight="bold")
plt.title('График относительного изменения кумулятивной конверсии',fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# В начале теста группа В вырывалась в лидеры, хотя была просадка по кумулятиву среднего чека в середине теста
# Делать какие либо выводы пока - нельзя, так как у нас было предположение о выбросах (крпных заказах), аномалиях

# %% [markdown]
# ### Постройте точечный `график количества заказов по пользователям`. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Подсчитаем количество заказов по пользователям

# %%
ordersByUsers = (
    df_orders.groupby('visitorid', as_index=False)
    .agg({'transactionid': pd.Series.nunique})
)

ordersByUsers.columns = ['userId', 'orders']

ordersByUsers.sort_values(by='orders', ascending=False).head(10)
# Out:
#           userId  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# 744   3062433592       5
# 55     237748145       5
# 917   3803269165       5
# 299   1230306981       5
# 897   3717692402       5

# %% [markdown]
# Построим точечную диаграмму

# %%
x_values = pd.Series(range(0,len(ordersByUsers['orders'])))
plt.figure(figsize=(15,8)) # размер графика
#plt.grid=True
plt.scatter(x_values, ordersByUsers['orders'])
# подписи графика
plt.ylabel('Заказов',fontsize = 15, fontweight="bold")
plt.xlabel('Кол-во пользователей',fontsize = 15, fontweight="bold")
plt.title('Точечный график количества заказов по пользователям',fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# Выводы подтверждаются: много пользователей с двумя и более заказами.
# Судя по графику, нормой можно считать 1-2 заказа

# %% [markdown]
# ### Посчитайте `95-й и 99-й перцентили количества заказов на пользователя`. Выберите границу для определения аномальных пользователей.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
print(np.percentile(ordersByUsers['orders'], [95, 99]))

# сохраним границу в переменную
number_border = np.percentile(ordersByUsers['orders'], [95])[0].round(0)
# Out:
# [2. 4.]

# %% [markdown]
# Не более 5% пользователей оформляли больше чем 2 заказа. И 1% пользователей заказывали 4 и более раз.

# %% [markdown]
# ### Постройте `точечный график стоимостей заказов`. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
x_values = pd.Series(range(0, len(df_orders['revenue'])))
plt.figure(figsize=(15,8)) # размер графика
plt.scatter(x_values,df_orders['revenue'])

# подписи графика
plt.ylabel('Стоимость',fontsize = 15, fontweight="bold")
plt.xlabel('Кол-во',fontsize = 15, fontweight="bold")
plt.title('Точечный график стоимостей заказов',fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# Выручка по заказам не превышает 100000, все что более аномалии или крупные заказы

# %% [markdown]
# ### Посчитайте `95-й и 99-й перцентили стоимости заказов`. Выберите границу для определения аномальных заказов.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %%
# Метод np.percentile('column', [percentile1, percentile2, percentile3]) находит перцентили.
print(np.percentile(df_orders['revenue'], [95, 99]))

# сохраним границу в переменную
revenue_border = np.percentile(df_orders['revenue'], [95])[0].round(0)
# Out:
# [28000.  58233.2]

# %% [markdown]
# Не более 5% стоимости заказов составили 28000. И 1% стоимости 58233.2 или более.
# Гарницей выбросов определим стомость заказов больше 28000, так как это не более 5% стоимости заказов - это и есть граница.

# %% [markdown]
# ### Посчитайте `статистическую значимость различий в конверсии между группами по «сырым» данным`. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Подготовка данных

# %%
visitorsADaily = df_visitors[df_visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = df_visitors[df_visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

ordersADaily = (
    df_orders[df_orders['group'] == 'A'][['date', 'transactionid', 'visitorid', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionid': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    df_orders[df_orders['group'] == 'B'][['date', 'transactionid', 'visitorid', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionid': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

data.head(5)
# Out:
#         date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0 2019-08-01              24           148579              21
# 1 2019-08-02              20            93822              24
# 2 2019-08-03              24           112473              16
# 3 2019-08-04              16            70825              17
# 4 2019-08-05              25           124218              23
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0           101217                  24               148579
# 1           165531                  44               242401
# 2           114248                  68               354874
# 3           108571                  84               425699
# 4            92428                 109               549917
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  21               101217               719
# 1                  45               266748               619
# ...

# %% [markdown]
# Статистическая значимость различий между конверсиями по "сырым" данным

# %% [markdown]
# Проверим гипотезы:
# `H0` : Статистических значимых различий в конверсии по "сырым" данным между группами нет
# `H1` : Статистических значимые различия в конверсии по "сырым" данным между группами имеются

# %% [markdown]
# Воспользуемся непараметрическим тестом Уилкоксона-Манна-Уитни `st.mannwhitneyu()` так как,
# в данных есть большие выбросы и в данном случае алгебраические метрики работают не корректно.

# %%
ordersByUsersA = (
    df_orders[df_orders['group'] == 'A']
    .groupby('visitorid', as_index=False)
    .agg({'transactionid': pd.Series.nunique}))

ordersByUsersA.columns = ['userId', 'orders']

ordersByUsersB = (
    df_orders[df_orders['group'] == 'B']
    .groupby('visitorid', as_index=False)
    .agg({'transactionid': pd.Series.nunique}))

ordersByUsersB.columns = ['userId', 'orders']

sampleA = pd.concat([ordersByUsersA['orders'],pd.Series(0,index=np.arange(
    data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])),name='orders',),],axis=0,)

sampleB = pd.concat([ordersByUsersB['orders'],pd.Series(0,index=np.arange(
    data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])),name='orders',),],axis=0,)

print("{0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))

print("{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# 0.008
# 0.138

# %%
print("{0:.1%}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# 13.8%

# %% [markdown]
# Первое число `p-value = 0.008` значит нулевую гипотезу о том, что статистических значимых различий в конверсии по "сырым" данным между группами нет, отвергаем.  При этом отличие по группе В составила 13.8%.
# Возможно ситтуация по чищенным данным изменит ситуацию

# %% [markdown]
# ### Посчитайте `статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным`. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Проверим гипотезы:
# `H0` : Статистических значимых различий в среднем чеке по "сырым" данным между группами нет
# `H1` : Статистических значимые различия в среднем чеке по "сырым" данным между группами имеются
#
# Воспользуемся непараметрическим тестом Уилкоксона-Манна-Уитни `st.mannwhitneyu()` так как,
# в данных есть большие выбросы и в данном случае алгебраические метрики работают не корректно.

# %%
print('{0:.3f}'.format(stats.mannwhitneyu(df_orders[df_orders['group']=='A']['revenue'], df_orders[df_orders['group']=='B']['revenue'])[1]))
print('{0:.3f}'.format(df_orders[df_orders['group']=='B']['revenue'].mean()/df_orders[df_orders['group']=='A']['revenue'].mean()-1))
# Out:
# 0.365
# 0.259

# %%
print('{0:.1%}'.format(df_orders[df_orders['group']=='B']['revenue'].mean()/df_orders[df_orders['group']=='A']['revenue'].mean()-1))
# Out:
# 25.9%

# %% [markdown]
# `P-value` значительно `больше 0.05`. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет.
# Отличие среднего чека между группами А и В, составляет `26%`

# %% [markdown]
# ### Посчитайте `статистическую значимость различий в конверсии между группами по «очищенным» данным`. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Узнаем, сколько всего аномальных пользователей
# Выборку сделаем на основе посчитанных ранее перцентелей и получившихся данных:
# * стоимость заказов больше 28000
# * кол-во заказов больше 2

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > number_border]['userId'],
        ordersByUsersB[ordersByUsersB['orders'] > number_border]['userId'],
    ],
    axis=0,
)
usersWithExpensiveOrders = df_orders[df_orders['revenue'] > revenue_border]['visitorid']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(abnormalUsers.head(5))
print(abnormalUsers.shape)
# Out:
# 1099    148427295
# 18      199603092
# 928     204675465
# 23      237748145
# 37      249864742
# dtype: int64
# (74,)

# %% [markdown]
# <div class="alert alert-info">
#
# Значения сохранил в переменные (`number_border` и `revenue_border`) выше по тексту, в `п.2.8-2.9`
# В `usersWithManyOrders` - значения заменил переменными
#
# </div>

# %% [markdown]
# Всего 74 аномальных пользователей.

# %% [markdown]
# Статистическая значимость различий в конверсии между группами по «очищенным» данным
#
# Проверим гипотезы:
# `H0` : Статистических значимых различий в конверсии по "очищенным" данным между группами нет
# `H1` : Статистических значимые различия в конверсии по "очищенным" данным между группами имеются

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print('{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# 0.007
# 0.173

# %% [markdown]
# Результаты по конверсии практически не изменились.
# *Результат по `"сырым"` данным:*
# 0.008
# 0.138
# *Результат по `"очищенным"` данным данным:*
# 0.005
# 0.177

# %% [markdown]
# `Отвергаем` нулевую гипотезу, о том что,
# `H0` : Статистических значимых различий в конверсии по `"очищенным"` данным между группами нет.
# Разница в конверсии есть как по `сырым` так и по `очищенным` данным

# %% [markdown]
# ### Посчитайте `статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным`. Сделайте выводы и предположения.

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)

# %% [markdown]
# Проверим гипотезы:
# `H0` : Статистических значимых различий в среднем чеке по "очищенным" данным между группами нет
# `H1` : Статистических значимые различия в среднем чеке по "очищенным" данным между группами имеются

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            df_orders[
                np.logical_and(
                    df_orders['group'] == 'A',
                    np.logical_not(df_orders['visitorid'].isin(abnormalUsers)),
                )
            ]['revenue'],
            df_orders[
                np.logical_and(
                    df_orders['group'] == 'B',
                    np.logical_not(df_orders['visitorid'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "{0:.3f}".format(
        df_orders[
            np.logical_and(
                df_orders['group'] == 'B',
                np.logical_not(df_orders['visitorid'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / df_orders[
            np.logical_and(
                df_orders['group'] == 'A',
                np.logical_not(df_orders['visitorid'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.369
# -0.020

# %% [markdown]
# P-value увеличился, но и разница между сегментами сократилась с 26% до 3%, что говорит о влиянии аномалий на A/B тест
# Результат по `"сырым"` данным:
# 0.365
# 0.259
# Результат по `"очищенным"` данным данным:
# 0.472
# 0.033

# %% [markdown]
# `Не удалось отвергнуть` нуевую гипотезу, о то что,
# `H0` : Статистических значимых различий в среднем чеке по "очищенным" данным между группами нет

# %% [markdown]
# ### Примите решение по результатам теста и объясните его.
# Варианты решений:
#     1. Остановить тест, зафиксировать победу одной из групп.
#     2. Остановить тест, зафиксировать отсутствие различий между группами.
#     3. Продолжить тест.

# %% [markdown]
# Всего выручка

# %%
df_orders['revenue'].sum()
# Out:
# 9992563

# %% [markdown]
# Выручка всего без аномальных пользователей

# %%
df_orders[~df_orders['visitorid'].isin(abnormalUsers)]['revenue'].sum()
# Out:
# 5280328

# %% [markdown]
# Выручка всего без аномальных пользователей по группе А

# %%
df_orders[~df_orders['visitorid'].isin(abnormalUsers)].query('group == "A"')['revenue'].sum()
# Out:
# 2443806

# %% [markdown]
# Выручка всего без аномальных пользователей по группе В

# %%
df_orders[~df_orders['visitorid'].isin(abnormalUsers)].query('group == "B"')['revenue'].sum()
# Out:
# 2836522

# %% [markdown]
# #### Сравнение выручки по группам без аномалий

# %%
print('Выручка по группе В больше группы А в относительном значении без выбросов, на :',
    '{0:.1%}'.format(df_orders[~df_orders['visitorid'].isin(abnormalUsers)].query('group == "B"')['revenue'].sum()/
     df_orders[~df_orders['visitorid'].isin(abnormalUsers)].query('group == "A"')['revenue'].sum()-1))
print('Выручка по группе В больше группы А в абсолютном значении без выбросов, на :',
    '{0:.1f}'.format(df_orders[~df_orders['visitorid'].isin(abnormalUsers)].query('group == "B"')['revenue'].sum()-
     df_orders[~df_orders['visitorid'].isin(abnormalUsers)].query('group == "A"')['revenue'].sum()))
# Out:
# Выручка по группе В больше группы А в относительном значении без выбросов, на : 16.1%
# Выручка по группе В больше группы А в абсолютном значении без выбросов, на : 392716.0

# %% [markdown]
# #### График кумулятивной выручки по дням и группам без аномалий

# %% [markdown]
# Построим графики на основании данных без выбросов

# %% [markdown]
# Исключим аномальных пользователей из выборки

# %%
df_orders_not_anomal = df_orders[~df_orders['visitorid'].isin(abnormalUsers)]

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = df_orders_not_anomal[['date','group']].drop_duplicates()
datesGroups.head()
# Out:
#          date group
# 0  2019-08-15     B
# 2  2019-08-15     A
# 45 2019-08-16     A
# 47 2019-08-16     B
# 55 2019-08-01     A

# %%
ordersAggregated = datesGroups.apply(lambda x: df_orders_not_anomal[np.logical_and(df_orders_not_anomal['date'] <= x['date'], df_orders_not_anomal['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transactionid' : 'nunique', 'visitorid' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])
visitorsAggregated = datesGroups.apply(lambda x: df_visitors[np.logical_and(df_visitors['date'] <= x['date'], df_visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия

cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]


plt.figure(figsize=(15,8)) # размер графика
# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

# градус подписей по оси Х
plt.xticks(rotation=45)

plt.legend()

plt.ylabel('Выручка',fontsize = 15, fontweight="bold")
plt.xlabel('Период',fontsize = 15, fontweight="bold")
plt.title('График кумулятивной выручки по дням и группам без аномалий',fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# Без выбросов данные по выручке стабильны и группа В лидирует

# %% [markdown]
# #### График кумулятивного среднего чека по группам без аномалий

# %%
plt.figure(figsize=(15,8)) # размер графика

plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.legend()

# градус подписей по оси Х
plt.xticks(rotation=45)

plt.ylabel('Средний чек',fontsize = 15, fontweight="bold")
plt.xlabel('Период',fontsize = 15, fontweight="bold")
plt.title('График кумулятивного среднего чека по группам без аномалий',fontsize = 15, fontweight="bold")
plt.show()

# %% [markdown]
# Как видим по группе В без выбросов средний чек больше, но к концу теста он выравнивается и различие не велико

# %% [markdown]
# Исходя из полученных данных:
# - **остановим тест и зафиксируем победу группы В**
#
# Так как выручка с аномалиями и без по группе `В больше > A`, средний чек группы `В` больше, несмотря на стабилизацию и приближение группы `А`, что поддталкивает на желание продолжить тест - делать мы это не будем, опираясь на данные `по выручке`.
#
# * согласно тестам нет разницы в среднем чеке между тестами, как по `сырым` так и `очищенным` данным, они незначительны
# * но есть значимая разница в конверсии между проводимыми тестами, в чем собственно и отличние
# * метрики стабилизировались к концу проведения теста и его можно закнчивать, так как выялено различие по конверсии группы В
#
# Исходя из изложенного: **остановим тест и зафиксируем победу группы В**

# %% [markdown]
# <a name="stage_1"></a>
#
# [Наверх к оглавлению](#contents)
